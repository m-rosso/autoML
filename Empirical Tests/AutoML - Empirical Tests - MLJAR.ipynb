# %% [markdown]
# ## AutoML
# ## Empirical Tests - MLJAR

# %% [markdown]
# This project aims to explore some of the main **AutoML tools** available, which involves the following tasks:
# 1. Reading of technical articles concerning the automated machine learning field.
# 2. Discussion about machine learning pipelines and the automation of some of their components.
# 3. Identification of the most interesting Python libraries for automatic ML pipeline construction.
# 4. Quick implementation of the selected tools with simulated data.
# 5. Careful exploration of the APIs of the selected tools.
# 6. Comparison among selected tools concerning: model performance, computation time, and usability.
#
# All of these activities derive from the **objectives** of this project, which are: i) reflection about ML pipeline components; ii) discussion and analysis of AutoML tools; iii) identification of key-points of AutoML frameworks; iv) definition of: the advantages and disadvantages of main AutoML tools, and, first of all, the relavance and adequacy of implementing AutoML.

# %% [markdown]
# ---------------------

# %% [markdown]
# In this series of notebooks, we test out different AutoML Python libraries and compare them according to the following criteria: performance metrics of developed pipelines evaluated on test data; computation time (i.e., the performance relative to the available time budget of the search process); and usability of the tool.
#
# * **Performance:** for each tool, after providing them with a training data (that will receive the appropriate validation approach by each tool), and after the search for the best ML pipeline, the selected one will be evaluated on a hold-out dataset (25% of the complete dataset). The model assessment will be based on the following metrics, since the supervised learning task is a binary classification here: [ROC-AUC](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html), [average precision score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html), [Brier score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.brier_score_loss.html), [accuracy](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html), and [MCC](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.matthews_corrcoef.html).
#
# * **Computation time:** all tested AutoML tools have some sort of time budget for the search process. Therefore, instead of minimizing the computation time across all tested tools, we will explore three different time budgets: 20 minutes, 1 hour, and 6 hours. Consequently, one of the main aspects of the comparison among tools will be the performance achieved by each one of them given different time budgets, besides of the average performance throughout all time budgets.
#
# * **Usability:** this aspect of the comparison refers to how easy it is to set up the search for each one of the tested tools. Also important are the outputs of the search process, mainly in terms of the visualization and assessment of constructed and selected pipelines. Besides, the diversity of produced information about the search and how clear it is to access and interpret these data are also an aspect to have in mind. Finally, the more straightforward it is to use a selected pipeline the better is the tool.
#
# The empirical tests follow the reading and discussing of the APIs of all selected tools. So, since the main initialization arguments, methods and attributes have been defined, they will be used accordingly in these notebooks.
#
# The data used for the empirical tests was found in Kaggle repository of datasets. It consists of a dataset for binary classification whose objective is to construct a classification algorithm for the [identification of malware apps](https://www.kaggle.com/saurabhshahane/android-permission-dataset). It has 27310 unique instances (mobile phone applications) and 184 variables, among which one is the binary outcome variable and another is the name of the app. Since the main objective of this project is to explore AutoML tools, only some basic feature engineering operations were implemented, besides of a short description and exploration of the data.

# %% [markdown]
# ------------

# %% [markdown]
# **Summary:**
# 1. [Libraries](#libraries)<a href='#libraries'></a>.
# 2. [Functions and classes](#functions_classes)<a href='#functions_classes'></a>.
# 3. [Settings](#settings)<a href='#settings'></a>.
# 4. [Importing datasets](#imports)<a href='#imports'></a>.
#     * [Features and outcome variables](#feats_outcomes)<a href='#feats_outcomes'></a>.
#
#
# 5. [Data description](#data_description)<a href='#data_description'></a>.
# 6. [ML pipeline](#ml_pipeline)<a href='#ml_pipeline'></a>.

# %% [markdown]
# <a id='libraries'></a>

# %% [markdown]
# ## Libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/MyDrive/Studies/autoML/Codes"
# Out:
# /content/gdrive/MyDrive/Studies/autoML/Codes

# %%
# pip install mljar-supervised

# %%
# pip install -r requirements.txt

# %%
# pip uninstall scikit-learn

# %%
# pip install scikit-learn==0.24.2

# %%
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime
from time import time
import pickle
from IPython.display import Markdown, display

from sklearn.metrics import roc_auc_score, accuracy_score, average_precision_score, brier_score_loss, accuracy_score, matthews_corrcoef

# pip install mljar-supervised
import supervised
from supervised import AutoML # MLJAR
print(f'MLJAR: version {supervised.__version__}.')
# Out:
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# MLJAR: version 0.11.0.

# %% [markdown]
# <a id='functions_classes'></a>

# %% [markdown]
# ## Functions and classes

# %%
from utils import running_time, correct_col_name, train_test_split
from pre_process import pre_process
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <a id='settings'></a>

# %% [markdown]
# ## Settings

# %% [markdown]
# ### Data management

# %%
# Identification of the test:
estimation_id = str(int(time()))

# Declare whether to export results:
export = True

# %% [markdown]
# ### ML pipeline search

# %% [markdown]
# #### Search complexity parameters

# %%
# Modes for the AutoML implementation:
# modes = ['Compete', 'Optuna']
modes = ['Optuna']

# Time budget (seconds) for the search:
total_time_limit = 6*60*60

# Time budget (seconds) for each developed model:
model_time_limit = None

# Time budget (seconds) for the Optuna hyperparameters tuning:
optuna_time_budget = int(total_time_limit/14)

# %% [markdown]
# #### Estimation parameters

# %%
# Whether an ensemble and stack of models should be constructed from the collection of tested models:
train_ensemble, stack_models = (True, True)

# Performance metric that should be optimized during the search:
eval_metric = 'auc'

# Dictionary with the validation strategy and its parameters:
validation_strategy = {'validation_type': 'kfold', 'k_folds': 5, 'shuffle': True, 'stratify': True}

# Level of explanations to produced for the final model:
explain_level = 2

# %% [markdown]
# #### Computation parameters

# %%
# Number of processes to use in parallel:
n_jobs = -1

# %% [markdown]
# <a id='imports'></a>

# %% [markdown]
# ## Importing datasets

# %% [markdown]
# <a id='feats_outcomes'></a>

# %% [markdown]
# ### Features and outcome variables

# %%
# Importing data:
df = pd.read_csv('../Datasets/Android_Permission.csv')

# Columns names:
df.columns = [correct_col_name(c) for c in df.columns]

# Auxiliary variables:
drop_vars = ['app', 'package', 'class']

# Removing duplicates:
df.drop_duplicates(inplace=True)

print(f'Shape of data: {df.shape}.')
df.head(3)
# Out:
# Shape of data: (27310, 184).
#                        app  ... class
# 0  Canada Post Corporation  ...     0
# 1                Word Farm  ...     0
# 2     Fortunes of War FREE  ...     0
#
# [3 rows x 184 columns]

# %% [markdown]
# #### Features names

# %%
features_names = list(df.drop(drop_vars, axis=1).columns)

for i in range(len(features_names)):
  print(features_names[i:i+10], '\n')
# Out:
# ['category', 'description', 'rating', 'number_of_ratings', 'price', 'related_apps', 'dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data']
#
# ['description', 'rating', 'number_of_ratings', 'price', 'related_apps', 'dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads']
#
# ['rating', 'number_of_ratings', 'price', 'related_apps', 'dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_']
#
# ['number_of_ratings', 'price', 'related_apps', 'dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_']
#
# ['price', 'related_apps', 'dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access']
#
# ['related_apps', 'dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_']
#
# ['dangerous_permissions_count', 'safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration']
#
# ['safe_permissions_count', 'access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings']
#
# ['access_drm_content_', 'access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources']
#
# ['access_email_provider_data', 'access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings']
#
# ['access_all_system_downloads', 'access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_']
#
# ['access_download_manager_', 'advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts']
#
# ['advanced_download_manager_functions_', 'audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger']
#
# ['audio_file_access', 'install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties']
#
# ['install_drm_content_', 'modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem']
#
# ['modify_google_service_configuration', 'modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts']
#
# ['modify_google_settings', 'move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator']
#
# ['move_application_resources', 'read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper']
#
# ['read_google_settings', 'send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method']
#
# ['send_download_notifications_', 'voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation']
#
# ['voice_search_shortcuts', 'access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse']
#
# ['access_surfaceflinger', 'access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications']
#
# ['access_checkin_properties', 'access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore']
#
# ['access_the_cache_filesystem', 'access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications']
#
# ['access_to_passwords_for_google_accounts', 'act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches']
#
# ['act_as_an_account_authenticator', 'bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data']
#
# ['bind_to_a_wallpaper', 'bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers']
#
# ['bind_to_an_input_method', 'change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications']
#
# ['change_screen_orientation', 'coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar']
#
# ['coarse', 'control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts']
#
# ['control_location_update_notifications', 'control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows']
#
# ['control_system_backup_and_restore', 'delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components']
#
# ['delete_applications', 'delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close']
#
# ['delete_other_applications_caches', 'delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot']
#
# ['delete_other_applications_data', 'directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access']
#
# ['directly_call_any_phone_numbers', 'directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin']
#
# ['directly_install_applications', 'disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens']
#
# ['disable_or_modify_status_bar', 'discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing']
#
# ['discover_known_accounts', 'display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics']
#
# ['display_unauthorized_windows', 'enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings']
#
# ['enable_or_disable_application_components', 'force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map']
#
# ['force_application_to_close', 'force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents']
#
# ['force_device_reboot', 'full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching']
#
# ['full_internet_access', 'interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown']
#
# ['interact_with_a_device_admin', 'manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device']
#
# ['manage_application_tokens', 'mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider']
#
# ['mock_location_sources_for_testing', 'modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off']
#
# ['modify_battery_statistics', 'modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons']
#
# ['modify_secure_system_settings', 'modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches']
#
# ['modify_the_google_services_map', 'modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer']
#
# ['modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages']
#
# ['monitor_and_control_all_application_launching', 'partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity']
#
# ['partial_shutdown', 'permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take']
#
# ['permanently_disable_device', 'permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults']
#
# ['permission_to_install_a_location_provider', 'power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode']
#
# ['power_device_on_or_off', 'press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time']
#
# ['press_keys_and_control_buttons', 'prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints']
#
# ['prevent_app_switches', 'read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service']
#
# ['read_frame_buffer', 'read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics']
#
# ['read_instant_messages', 'read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data']
#
# ['read_phone_state_and_identity', 'record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages']
#
# ['record_what_you_type_and_actions_you_take', 'reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging']
#
# ['reset_system_to_factory_defaults', 'run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes']
#
# ['run_in_factory_test_mode', 'set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close']
#
# ['set_time', 'set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications']
#
# ['set_wallpaper_size_hints', 'start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings']
#
# ['start_im_service', 'update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight']
#
# ['update_component_usage_statistics', 'write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator']
#
# ['write_contact_data', 'write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio']
#
# ['write_instant_messages', 'development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos']
#
# ['development_tools_enable_application_debugging', 'development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware']
#
# ['development_tools_limit_number_of_running_processes', 'development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_']
#
# ['development_tools_make_all_background_applications_close', 'development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication']
#
# ['development_tools_send_linux_signals_to_applications', 'hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections']
#
# ['hardware_controls_change_your_audio_settings', 'hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification']
#
# ['hardware_controls_control_flashlight', 'hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access']
#
# ['hardware_controls_control_vibrator', 'hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls']
#
# ['hardware_controls_record_audio', 'hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet']
#
# ['hardware_controls_take_pictures_and_videos', 'hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state']
#
# ['hardware_controls_test_hardware', 'network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state']
#
# ['network_communication_broadcast_data_messages_to_applications_', 'network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls']
#
# ['network_communication_control_near_field_communication', 'network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state']
#
# ['network_communication_create_bluetooth_connections', 'network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity']
#
# ['network_communication_download_files_without_notification', 'network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers']
#
# ['network_communication_full_internet_access', 'network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages']
#
# ['network_communication_make_receive_internet_calls', 'network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents']
#
# ['network_communication_receive_data_from_internet', 'network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception']
#
# ['network_communication_view_wi_fi_state', 'network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot']
#
# ['network_communication_view_network_state', 'phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration']
#
# ['phone_calls_intercept_outgoing_calls', 'phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state']
#
# ['phone_calls_modify_phone_state', 'phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting']
#
# ['phone_calls_read_phone_state_and_identity', 'services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity']
#
# ['services_that_cost_you_money_directly_call_phone_numbers', 'services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings']
#
# ['services_that_cost_you_money_send_sms_messages', 'storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data']
#
# ['storage_modify_delete_usb_storage_contents_modify_delete_sd_card_contents', 'system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock']
#
# ['system_tools_allow_wi_fi_multicast_reception', 'system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts']
#
# ['system_tools_automatically_start_at_boot', 'system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar']
#
# ['system_tools_bluetooth_administration', 'system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications']
#
# ['system_tools_change_wi_fi_state', 'system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage']
#
# ['system_tools_change_background_data_usage_setting', 'system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes']
#
# ['system_tools_change_network_connectivity', 'system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run']
#
# ['system_tools_change_your_ui_settings', 'system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space']
#
# ['system_tools_delete_all_application_cache_data', 'system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed']
#
# ['system_tools_disable_keylock', 'system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings']
#
# ['system_tools_display_system_level_alerts', 'system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems']
#
# ['system_tools_expand_collapse_status_bar', 'system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping']
#
# ['system_tools_force_stop_other_applications', 'system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds']
#
# ['system_tools_format_external_storage', 'system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings']
#
# ['system_tools_kill_background_processes', 'system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics']
#
# ['system_tools_make_application_always_run', 'system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag']
#
# ['system_tools_measure_application_storage_space', 'system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications']
#
# ['system_tools_modify_global_animation_speed', 'system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications']
#
# ['system_tools_modify_global_system_settings', 'system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast']
#
# ['system_tools_mount_and_unmount_filesystems', 'system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast']
#
# ['system_tools_prevent_device_from_sleeping', 'system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications']
#
# ['system_tools_read_subscribed_feeds', 'system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone']
#
# ['system_tools_read_sync_settings', 'system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper']
#
# ['system_tools_read_sync_statistics', 'system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints']
#
# ['system_tools_read_write_to_resources_owned_by_diag', 'system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings']
#
# ['system_tools_reorder_running_applications', 'system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds']
#
# ['system_tools_retrieve_running_applications', 'system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings']
#
# ['system_tools_send_package_removed_broadcast', 'system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings', 'your_accounts_blogger']
#
# ['system_tools_send_sticky_broadcast', 'system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings', 'your_accounts_blogger', 'your_accounts_google_app_engine']
#
# ['system_tools_set_preferred_applications', 'system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings', 'your_accounts_blogger', 'your_accounts_google_app_engine', 'your_accounts_google_docs']
#
# ['system_tools_set_time_zone', 'system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings', 'your_accounts_blogger', 'your_accounts_google_app_engine', 'your_accounts_google_docs', 'your_accounts_google_finance']
#
# ['system_tools_set_wallpaper', 'system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings', 'your_accounts_blogger', 'your_accounts_google_app_engine', 'your_accounts_google_docs', 'your_accounts_google_finance', 'your_accounts_google_maps']
#
# ['system_tools_set_wallpaper_size_hints', 'system_tools_write_access_point_name_settings', 'system_tools_write_subscribed_feeds', 'system_tools_write_sync_settings', 'your_accounts_blogger', 'your_accounts_google_app_engine', 'your_accounts_google_docs', 'your_accounts_google_finance', 'your_accounts_google_maps', 'your_accounts_google_spreadsheets']
#
# ...
#
# ['your_accounts_access_other_google_services', 'your_accounts_act_as_an_account_authenticator', 'your_accounts_act_as_the_accountmanagerservice', 'your_accounts_contacts_data_in_google_accounts', 'your_accounts_discover_known_accounts', 'your_accounts_manage_the_accounts_list', 'your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands']
#
# ['your_accounts_act_as_an_account_authenticator', 'your_accounts_act_as_the_accountmanagerservice', 'your_accounts_contacts_data_in_google_accounts', 'your_accounts_discover_known_accounts', 'your_accounts_manage_the_accounts_list', 'your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse']
#
# ['your_accounts_act_as_the_accountmanagerservice', 'your_accounts_contacts_data_in_google_accounts', 'your_accounts_discover_known_accounts', 'your_accounts_manage_the_accounts_list', 'your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine']
#
# ['your_accounts_contacts_data_in_google_accounts', 'your_accounts_discover_known_accounts', 'your_accounts_manage_the_accounts_list', 'your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing']
#
# ['your_accounts_discover_known_accounts', 'your_accounts_manage_the_accounts_list', 'your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments']
#
# ['your_accounts_manage_the_accounts_list', 'your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail']
#
# ['your_accounts_read_google_service_configuration', 'your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms']
#
# ['your_accounts_use_the_authentication_credentials_of_an_account', 'your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail']
#
# ['your_accounts_view_configured_accounts', 'your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail']
#
# ['your_location_access_extra_location_provider_commands', 'your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews']
#
# ['your_location_coarse', 'your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms']
#
# ['your_location_fine', 'your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages']
#
# ['your_location_mock_location_sources_for_testing', 'your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms']
#
# ['your_messages_read_email_attachments', 'your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms']
#
# ['your_messages_send_gmail', 'your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap']
#
# ['your_messages_edit_sms_or_mms', 'your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast']
#
# ['your_messages_modify_gmail', 'your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast']
#
# ['your_messages_read_gmail', 'your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages']
#
# ['your_messages_read_gmail_attachment_previews', 'your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests']
#
# ['your_messages_read_sms_or_mms', 'your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets']
#
# ['your_messages_read_instant_messages', 'your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks']
#
# ['your_messages_receive_mms', 'your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events']
#
# ['your_messages_receive_sms', 'your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data']
#
# ['your_messages_receive_wap', 'your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data']
#
# ['your_messages_send_sms_received_broadcast', 'your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary']
#
# ['your_messages_send_wap_push_received_broadcast', 'your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state']
#
# ['your_messages_write_instant_messages', 'your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock']
#
# ['your_personal_information_add_or_modify_calendar_events_and_send_email_to_guests', 'your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks']
#
# ['your_personal_information_choose_widgets', 'your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data']
#
# ['your_personal_information_read_browsers_history_and_bookmarks', 'your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_read_calendar_events', 'your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_read_contact_data', 'your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_read_sensitive_log_data', 'your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_read_user_defined_dictionary', 'your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_retrieve_system_internal_state', 'your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_set_alarm_in_alarm_clock', 'your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_write_browsers_history_and_bookmarks', 'your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_write_contact_data', 'your_personal_information_write_to_user_defined_dictionary']
#
# ['your_personal_information_write_to_user_defined_dictionary']

# %% [markdown]
# #### Data types

# %%
data_types = pd.DataFrame(df.dtypes, columns=['type']).reset_index(drop=False)
data_types.columns = ['feature', 'type']

print('\033[1mDistribution of data types:\033[0m')
print(data_types.type.value_counts())
# Out:
# Distribution of data types:
# int64      176
# object       5
# float64      3
# Name: type, dtype: int64

# %% [markdown]
# #### Train-test split

# %%
df_train, df_test = train_test_split(df, test_ratio=0.25, shuffle=True)

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# Related apps

# %%
# Creating the variable with the number of related apps:
df_train['related_apps'] = df_train['related_apps'].apply(lambda x: x if pd.isna(x) else x.replace('{', '').replace('}', ''))
df_train['num_related_apps'] = df_train.related_apps.apply(lambda x: x if pd.isna(x) else len(x.split(',')))
df_test['num_related_apps'] = df_test.related_apps.apply(lambda x: x if pd.isna(x) else len(x.split(',')))

# Updating the list of auxiliary variables:
drop_vars.append('related_apps')

# %% [markdown]
# Description

# %%
# Creating the variable that indicates the number of words in a description:
df_train['num_words_desc'] = df_train.description.apply(lambda x: x if pd.isna(x) else len(x.split(' ')))
df_test['num_words_desc'] = df_test.description.apply(lambda x: x if pd.isna(x) else len(x.split(' ')))

# Updating the list of auxiliary variables:
drop_vars.append('description')

# %% [markdown]
# Category

# %% [markdown]
# Even though this feature engineering is actually a transformation applied over categorical features, we first implement one-hot encoding in order to translate this categorical attribute into a numerical one, since some AutoML tools explored within this project do not allow textual inputs.

# %%
from transformations import applying_one_hot

# %%
transf_data = applying_one_hot(training_data=df_train, cat_vars=['category'], variance_param=-1, test_data=df_test)
df_train = transf_data['training_data']
df_test = transf_data['test_data']
# Out:
# Number of categorical features: 1
# Number of overall selected dummies: 30.

# %% [markdown]
# <a id='data_description'></a>

# %% [markdown]
# ## Data description

# %% [markdown]
# <a id='features_types'></a>

# %% [markdown]
# ### Features types

# %%
feature_types = pd.DataFrame(df_train.drop(drop_vars, axis=1).dtypes, columns=['type']).reset_index(drop=False)
feature_types.columns = ['feature', 'type']

print('\033[1mDistribution of data types (features):\033[0m')
print(feature_types.type.value_counts())
# Out:
# Distribution of data types (features):
# int64      175
# uint8       30
# float64      5
# Name: type, dtype: int64

# %% [markdown]
# <a id='ml_pipeline'></a>

# %% [markdown]
# ## ML pipeline

# %%
help(AutoML)
# Out:
# Help on class AutoML in module supervised.automl:
#
# class AutoML(supervised.base_automl.BaseAutoML)
#  |  AutoML(results_path=None, total_time_limit=3600, mode='Explain', ml_task='auto', model_time_limit=None, algorithms='auto', train_ensemble=True, stack_models='auto', eval_metric='auto', validation_strategy='auto', explain_level='auto', golden_features='auto', features_selection='auto', start_random_models='auto', hill_climbing_steps='auto', top_models_to_improve='auto', boost_on_errors='auto', kmeans_features='auto', mix_encoding='auto', max_single_prediction_time=None, optuna_time_budget=None, optuna_init_params={}, optuna_verbose=True, n_jobs=-1, verbose=1, random_state=1234)
#  |
#  |  Automated Machine Learning for supervised tasks (binary classification, multiclass classification, regression).
#  |
#  |  Method resolution order:
#  |      AutoML
#  |      supervised.base_automl.BaseAutoML
#  |      sklearn.base.BaseEstimator
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, results_path=None, total_time_limit=3600, mode='Explain', ml_task='auto', model_time_limit=None, algorithms='auto', train_ensemble=True, stack_models='auto', eval_metric='auto', validation_strategy='auto', explain_level='auto', golden_features='auto', features_selection='auto', start_random_models='auto', hill_climbing_steps='auto', top_models_to_improve='auto', boost_on_errors='auto', kmeans_features='auto', mix_encoding='auto', max_single_prediction_time=None, optuna_time_budget=None, optuna_init_params={}, optuna_verbose=True, n_jobs=-1, verbose=1, random_state=1234)
#  |      Initialize `AutoML` object.
#  |
#  |      Arguments:
#  |          results_path (str): The path with results. If None, then the name of directory will be generated with the template: AutoML_{number},
#  |              where the number can be from 1 to 1,000 - depends which direcory name will be available.
#  |              If the `results_path` will point to directory with AutoML results (`params.json` must be present),
#  |              then all models will be loaded.
#  |
#  |          total_time_limit (int): The total time limit in seconds for AutoML training.
#  |              It is not used when `model_time_limit` is not `None`.
#  |
#  |          mode (str): Can be {`Explain`, `Perform`, `Compete`, `Optuna`}. This parameter defines the goal of AutoML and how intensive the AutoML search will be.
#  |
#  |              - `Explain` : To to be used when the user wants to explain and understand the data.
#  |                  - Uses 75%/25% train/test split.
#  |                  - Uses the following models: `Baseline`, `Linear`, `Decision Tree`, `Random Forest`, `XGBoost`, `Neural Network`, and `Ensemble`.
#  |                  - Has full explanations in reports: learning curves, importance plots, and SHAP plots.
#  |              - `Perform` : To be used when the user wants to train a model that will be used in real-life use cases.
#  |                  - Uses 5-fold CV (Cross-Validation).
#  |                  - Uses the following models: `Linear`, `Random Forest`, `LightGBM`, `XGBoost`, `CatBoost`, `Neural Network`, and `Ensemble`.
#  |                  - Has learning curves and importance plots in reports.
#  |              - `Compete` : To be used for machine learning competitions (maximum performance).
#  |                  - Uses 80/20 train/test split, or 5-fold CV, or 10-fold CV (Cross-Validation) - it depends on `total_time_limit`. If not set directly, AutoML will select validation automatically.
#  |                  - Uses the following models: `Decision Tree`, `Random Forest`, `Extra Trees`, `LightGBM`,  `XGBoost`, `CatBoost`, `Neural Network`,
#  |                      `Nearest Neighbors`, `Ensemble`, and `Stacking`.
#  |                  - It has only learning curves in the reports.
#  |              - `Optuna` : To be used for creating highly-tuned machine learning models.
#  |                  - Uses 10-fold CV (Cross-Validation).
#  |                  - It tunes with Optuna the following algorithms: `Random Forest`, `Extra Trees`, `LightGBM`, `XGBoost`, `CatBoost`, `Neural Network`.
#  |                  - It applies `Ensemble` and `Stacking` for trained models.
#  |                  - It has only learning curves in the reports.
#  |
#  |          ml_task (str): Can be {"auto", "binary_classification", "multiclass_classification", "regression"}.
#  |
#  |              - If left `auto` AutoML will try to guess the task based on target values.
#  |              - If there will be only 2 values in the target, then task will be set to `"binary_classification"`.
#  |              - If number of values in the target will be between 2 and 20 (included), then task will be set to `"multiclass_classification"`.
#  |              - In all other casses, the task is set to `"regression"`.
#  |
#  |          model_time_limit (int): The time limit for training a single model, in seconds.
#  |              If `model_time_limit` is set, the `total_time_limit` is not respected.
#  |              The single model can contain several learners. The time limit for subsequent learners is computed based on `model_time_limit`.
#  |
#  |              For example, in the case of 10-fold cross-validation, one model will have 10 learners.
#  |              The `model_time_limit` is the time for all 10 learners.
#  |
#  |          algorithms (list of str): The list of algorithms that will be used in the training.
#  |              The algorithms can be:
#  |
#  |              - `Baseline`,
#  |              - `Linear`,
#  |              - `Decision Tree`,
#  |              - `Random Forest`,
#  |              - `Extra Trees`,
#  |              - `LightGBM`,
#  |              - `Xgboost`,
#  |              - `CatBoost`,
#  |              - `Neural Network`,
#  |              - `Nearest Neighbors`,
#  |
#  |
#  |          train_ensemble (boolean): Whether an ensemble gets created at the end of the training.
#  |
#  |          stack_models (boolean): Whether a models stack gets created at the end of the training. Stack level is 1.
#  |
#  |          eval_metric (str): The metric to be used in early stopping and to compare models.
#  |
#  |              - for binary classification: `logloss`, `auc`, `f1`, `average_precision`, `accuracy` - default is logloss (if left "auto")
#  |              - for mutliclass classification: `logloss`, `f1`, `accuracy` - default is `logloss` (if left "auto")
#  |              - for regression: `rmse`, `mse`, `mae`, `r2`, `mape`, `spearman`, `pearson` - default is `rmse` (if left "auto")
#  |
#  |          validation_strategy (dict): Dictionary with validation type. Right now train/test split and cross-validation are supported.
#  |
#  |              Example:
#  |
#  |                  Cross-validation exmaple:
#  |                  {
#  |                      "validation_type": "kfold",
#  |                      "k_folds": 5,
#  |                      "shuffle": True,
#  |                      "stratify": True,
#  |                      "random_seed": 123
#  |                  }
#  |
#  |                  Train/test example:
#  |                  {
#  |                      "validation_type": "split",
#  |                      "train_ratio": 0.75,
#  |                      "shuffle": True,
#  |                      "stratify": True
#  |                  }
#  |
#  |          explain_level (int): The level of explanations included to each model:
#  |
#  |              - if `explain_level` is `0` no explanations are produced.
#  |              - if `explain_level` is `1` the following explanations are produced: importance plot (with permutation method), for decision trees produce tree plots, for linear models save coefficients.
#  |              - if `explain_level` is `2` the following explanations are produced: the same as `1` plus SHAP explanations.
#  |
#  |              If left `auto` AutoML will produce explanations based on the selected `mode`.
#  |
#  |          golden_features (boolean or int): Whether to use golden features (and how many should be added)
#  |              If left `auto` AutoML will use golden features based on the selected `mode`:
#  |
#  |              - If `mode` is "Explain", `golden_features` = False.
#  |              - If `mode` is "Perform", `golden_features` = True.
#  |              - If `mode` is "Compete", `golden_features` = True.
#  |
#  |              If `boolean` value is set then the number of Golden Features is set automatically.
#  |              It is set to min(100, max(10, 0.1*number_of_input_features)).
#  |
#  |              If `int` value is set, the number of Golden Features is set to this value.
#  |
#  |          features_selection (boolean): Whether to do features_selection
#  |              If left `auto` AutoML will do feature selection based on the selected `mode`:
#  |
#  |              - If `mode` is "Explain", `features_selection` = False.
#  |              - If `mode` is "Perform", `features_selection` = True.
#  |              - If `mode` is "Compete", `features_selection` = True.
#  |
#  |          start_random_models (int): Number of starting random models to try.
#  |              If left `auto` AutoML will select it based on the selected `mode`:
#  |
#  |              - If `mode` is "Explain", `start_random_models` = 1.
#  |              - If `mode` is "Perform", `start_random_models` = 5.
#  |              - If `mode` is "Compete", `start_random_models` = 10.
#  |
#  |          hill_climbing_steps (int): Number of steps to perform during hill climbing.
#  |              If left `auto` AutoML will select it based on the selected `mode`:
#  |
#  |              - If `mode` is "Explain", `hill_climbing_steps` = 0.
#  |              - If `mode` is "Perform", `hill_climbing_steps` = 2.
#  |              - If `mode` is "Compete", `hill_climbing_steps` = 2.
#  |
#  |          top_models_to_improve (int): Number of best models to improve in `hill_climbing` steps.
#  |              If left `auto` AutoML will select it based on the selected `mode`:
#  |
#  |              - If `mode` is "Explain", `top_models_to_improve` = 0.
#  |              - If `mode` is "Perform", `top_models_to_improve` = 2.
#  |              - If `mode` is "Compete", `top_models_to_improve` = 3.
#  |
#  |          boost_on_errors (boolean): Whether a model with boost on errors from previous best model should be trained. By default available in the `Compete` mode.
#  |
#  |          kmeans_features (boolean): Whether a model with k-means generated features should be trained. By default available in the `Compete` mode.
#  |
#  |          mix_encoding (boolean): Whether a model with mixed encoding should be trained. Mixed encoding is the encoding that uses label encoding
#  |              for categoricals with more than 25 categories, and one-hot binary encoding for other categoricals. It is only applied if there are
#  |              categorical features with cardinality smaller than 25. By default it is available in the `Compete` mode.
#  |
#  |          max_single_prediction_time (int or float): The limit for prediction time for single sample. Use it if you want to have a model with fast predictions.
#  |              Ideal for creating ML pipelines used as REST API. Time is in seconds. By default (`max_single_prediction_time=None`) models are not optimized for fast predictions,
#  |              except the mode `Perform`. For the mode `Perform` the default is `0.5` seconds.
#  |
#  |          optuna_time_budget (int): The time in seconds which should be used by Optuna to tune each algorithm. It is time for tuning single algorithm.
#  |              If you select two algorithms: Xgboost and CatBoost, and set optuna_time_budget=1000, then Xgboost will be tuned for 1000 seconds and CatBoost will be tuned for 1000 seconds.
#  |              What is more, the tuning is made for each data type, for example for raw data and for data with inserted Golden Features.
#  |              This parameter is only used when `mode="Optuna"`. If you set `mode="Optuna"` and forget to set this parameter, it will be set to 3600 seconds.
#  |
#  |          optuna_init_params (dict): If you have already tuned parameters from Optuna you can reuse them by setting this parameter.
#  |              This parameter is only used when `mode="Optuna"`. The dict should have structure and params as specified in the MLJAR AutoML .
#  |
#  |          optuna_verbose (boolean): If true the Optuna tuning details are displayed. Set to `True` by default.
#  |
#  |          n_jobs (int): Number of CPU cores to be used. By default is set to `-1` which means using  all processors.
#  |
#  |          verbose (int): Controls the verbosity when fitting and predicting.
#  |
#  |              Note:
#  |                  Still not implemented, please left `1`
#  |
#  |          random_state (int): Controls the randomness of the `AutoML`
#  |
#  |
#  |      Examples:
#  |
#  |          Binary Classification Example:
#  |
#  |          >>> import pandas as pd
#  |          >>> from sklearn.model_selection import train_test_split
#  |          >>> from sklearn.metrics import roc_auc_score
#  |          >>> from supervised import AutoML
#  |          >>> df = pd.read_csv(
#  |          ...        "https://raw.githubusercontent.com/pplonski/datasets-for-start/master/adult/data.csv",
#  |          ...       skipinitialspace=True
#  |          ...    )
#  |          >>> X_train, X_test, y_train, y_test = train_test_split(
#  |          ... df[df.columns[:-1]], df["income"], test_size=0.25
#  |          ... )
#  |          >>> automl = AutoML()
#  |          >>> automl.fit(X_train, y_train)
#  |          >>> y_pred_prob = automl.predict_proba(X_test)
#  |          >>> print(f"AUROC: {roc_auc_score(y_test, y_pred_prob):.2f}%")
#  |
#  |
#  |          Multi-Class Classification Example:
#  |
#  |          >>> import pandas as pd
#  |          >>> from sklearn.datasets import load_digits
#  |          >>> from sklearn.metrics import accuracy_score
#  |          >>> from sklearn.model_selection import train_test_split
#  |          >>> from supervised import AutoML
#  |          >>> digits = load_digits()
#  |          >>> X_train, X_test, y_train, y_test = train_test_split(
#  |          ...     digits.data, digits.target, stratify=digits.target, test_size=0.25,
#  |          ...     random_state=123
#  |          ... )
#  |          >>> automl = AutoML(mode="Perform")
#  |          >>> automl.fit(X_train, y_train)
#  |          >>> y_pred = automl.predict(X_test)
#  |          >>> print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}%")
#  |
#  |          Regression Example:
#  |
#  |          >>> import pandas as pd
#  |          >>> from sklearn.datasets import load_boston
#  |          >>> from sklearn.model_selection import train_test_split
#  |          >>> from sklearn.metrics import mean_squared_error
#  |          >>> from supervised import AutoML
#  |          >>> housing = load_boston()
#  |          >>> X_train, X_test, y_train, y_test = train_test_split(
#  |          ...       pd.DataFrame(housing.data, columns=housing.feature_names),
#  |          ...       housing.target,
#  |          ...       test_size=0.25,
#  |          ...       random_state=123,
#  |          ... )
#  |          >>> automl = AutoML(mode="Compete")
#  |          >>> automl.fit(X_train, y_train)
#  |          >>> print("Test R^2:", automl.score(X_test, y_test))
#  |
#  |          Scikit-learn Pipeline Integration Example:
#  |
#  |          >>> from imblearn.over_sampling import RandomOverSampler
#  |          >>> from sklearn.pipeline import make_pipeline
#  |          >>> from sklearn.datasets import make_classification
#  |          >>> from sklearn.model_selection import train_test_split
#  |          >>> from supervised import AutoML
#  |          >>> X, y = make_classification()
#  |          >>> X_train, X_test, y_train, y_test = train_test_split(X,y)
#  |          >>> pipeline = make_pipeline(RandomOverSampler(), AutoML())
#  |          >>> print(pipeline.fit(X_train, y_train).score(X_test, y_test))
#  |
#  |  fit(self, X, y, sample_weight=None, cv=None)
#  |      Fit the AutoML model.
#  |
#  |      Arguments:
#  |          X (numpy.ndarray or pandas.DataFrame): Training data
#  |
#  |          y (numpy.ndarray or pandas.Series): Training targets
#  |
#  |          sample_weight (numpy.ndarray or pandas.Series): Training sample weights
#  |
#  |          cv (iterable or list): List or iterable with (train, validation) splits representing array of indices.
#  |          It is used only with custom validation (`validation_strategy={'validation_type': 'custom'}`).
#  |
#  |      Returns:
#  |          AutoML object: Returns `self`
#  |
#  |  need_retrain(self, X, y, sample_weight=None, decrease=0.1)
#  |      Decides about model retraining based on new data.
#  |
#  |      Arguments:
#  |          X (numpy.ndarray or pandas.DataFrame):
#  |              New data.
#  |
#  |          y (numpy.ndarray or pandas.Series):
#  |              True labels for X.
#  |
#  |          sample_weight (numpy.ndarray or pandas.Series):
#  |              Sample weights.
#  |
#  |          decrease (float): The ratio of change in the performance used as a threshold for retraining decision.
#  |              By default, it is set to `0.1` which means that if the performance of AutoML will decrease by 10%
#  |              on new data then there is a need to retrain. This value should be set depending on your project needs.
#  |              Sometimes, 10% is enough, but for some projects, it can be even lower than 1%.
#  |
#  |          Returns:
#  |              boolean: Decides if there is a need to retrain the AutoML.
#  |
#  |  predict(self, X)
#  |      Computes predictions from AutoML best model.
#  |
#  |      Arguments:
#  |          X (list or numpy.ndarray or pandas.DataFrame):
#  |              Input values to make predictions on.
#  |
#  |      Returns:
#  |          numpy.ndarray:
#  |
#  |          - One-dimensional array of class labels for classification.
#  |          - One-dimensional array of predictions for regression.
#  |
#  |      Raises:
#  |          AutoMLException: Model has not yet been fitted.
#  |
#  |  predict_all(self, X)
#  |      Computes both class probabilities and class labels for classification tasks.
#  |      Computes predictions for regression tasks.
#  |
#  |      Arguments:
#  |          X (list or numpy.ndarray or pandas.DataFrame):
#  |              Input values to make predictions on.
#  |
#  |      Returns:
#  |          pandas.Dataframe:
#  |              Dataframe (n_samples, n_classes + 1) containing both class probabilities and class
#  |              labels of the input samples for classification tasks.
#  |              Dataframe with predictions for regression tasks.
#  |
#  |      Raises:
#  |          AutoMLException: Model has not yet been fitted.
#  |
#  |  predict_proba(self, X)
#  |      Computes class probabilities from AutoML best model.
#  |      This method can only be used for classification tasks.
#  |
#  |      Arguments:
#  |          X (list or numpy.ndarray or pandas.DataFrame):
#  |              Input values to make predictions on.
#  |
#  |      Returns:
#  |          numpy.ndarray of shape (n_samples, n_classes):
#  |              Matrix of containing class probabilities of the input samples
#  |
#  |      Raises:
#  |          AutoMLException: Model has not yet been fitted.
#  |
#  |  report(self, width=900, height=1200)
#  |
#  |  score(self, X, y=None, sample_weight=None)
#  |      Calculates a goodness of `fit` for an AutoML instance.
#  |
#  |      Arguments:
#  |          X (numpy.ndarray or pandas.DataFrame):
#  |              Test values to make predictions on.
#  |
#  |          y (numpy.ndarray or pandas.Series):
#  |              True labels for X.
#  |
#  |          sample_weight (numpy.ndarray or pandas.Series):
#  |              Sample weights.
#  |      Returns:
#  |          float: Returns a goodness of fit measure (higher is better):
#  |
#  |          - For classification tasks: returns the mean accuracy on the given test data and labels.
#  |          - For regression tasks: returns the R^2 (coefficient of determination) on the given test data and labels.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from supervised.base_automl.BaseAutoML:
#  |
#  |  can_we_stack_them(self, y)
#  |
#  |  create_dir(self, model_path)
#  |
#  |  ensemble_step(self, is_stacked=False)
#  |
#  |  from_json(self, json_data)
#  |
#  |  get_leaderboard(self, filter_random_feature=False, original_metric_values=False)
#  |
#  |  get_stacked_data(self, X, mode='training')
#  |
#  |  get_stacking_minimum_time_needed(self)
#  |
#  |  keep_model(self, model, model_subpath)
#  |
#  |  load(self, path)
#  |
#  |  load_progress(self)
#  |
#  |  prepare_for_stacking(self)
#  |
#  |  save_progress(self, step=None, generated_params=None)
#  |
#  |  select_and_save_best(self, show_warnings=False)
#  |
#  |  to_json(self)
#  |
#  |  train_model(self, params)
#  |
#  |  verbose_print(self, msg)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from supervised.base_automl.BaseAutoML:
#  |
#  |  report_style = '\n.styled-table {\n    border-collapse: collapse;\n......
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.BaseEstimator:
#  |
#  |  __getstate__(self)
#  |
#  |  __repr__(self, N_CHAR_MAX=700)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  get_params(self, deep=True)
#  |      Get parameters for this estimator.
#  |
#  |      Parameters
#  |      ----------
#  |      deep : bool, default=True
#  |          If True, will return the parameters for this estimator and
#  |          contained subobjects that are estimators.
#  |
#  |      Returns
#  |      -------
#  |      params : dict
#  |          Parameter names mapped to their values.
#  |
#  |  set_params(self, **params)
#  |      Set the parameters of this estimator.
#  |
#  |      The method works on simple estimators as well as on nested objects
#  |      (such as :class:`~sklearn.pipeline.Pipeline`). The latter have
#  |      parameters of the form ``<component>__<parameter>`` so that it's
#  |      possible to update each component of a nested object.
#  |
#  |      Parameters
#  |      ----------
#  |      **params : dict
#  |          Estimator parameters.
#  |
#  |      Returns
#  |      -------
#  |      self : estimator instance
#  |          Estimator instance.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sklearn.base.BaseEstimator:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# <a id='ml_pipeline_search'></a>

# %% [markdown]
# ### ML pipeline search

# %% [markdown]
# #### Setting and running the search

# %%
# Dictionary with the model of each implemented AutoML mode:
models = {}
search_times = {}

for mode in modes:
  # Path to the folder where outcomes should be placed:
  results_path = f'../Datasets/Outcomes/mljar/{mode}/{estimation_id}'

  # Creating the AutoML object:
  models[mode] = AutoML(
      # Search complexity parameters:
      mode=mode, total_time_limit=total_time_limit, model_time_limit=model_time_limit, optuna_time_budget=optuna_time_budget,
      
      # Estimation parameters:
      train_ensemble=train_ensemble, stack_models=stack_models, eval_metric=eval_metric, validation_strategy=validation_strategy,

      # Computation parameters:
      results_path=results_path, n_jobs=n_jobs,
                  )

  start_time = datetime.now()

  # Running the search:
  models[mode].fit(df_train.drop(drop_vars, axis=1), df_train['class'])

  # Total elapsed time:
  end_time = datetime.now()
  search_times[mode] = running_time(start_time=start_time, end_time=end_time)
# Out:
# AutoML directory: ../Datasets/Outcomes/mljar/Optuna/1631290500
# Expected computing time:
# Time for tuning with Optuna: len(algorithms) * optuna_time_budget = 9252 seconds
# There is no time limit for ML model training after Optuna tuning (total_time_limit parameter is ignored).
# The task is binary_classification with evaluation metric auc
# AutoML will use algorithms: ['Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble', 'stack', 'ensemble_stacked']
# Skip simple_algorithms because no parameters were generated.
# * Step default_algorithms will try to check up to 6 models
# [I 2021-09-10 16:15:24,606] A new study created in memory with name: no-name-06c5079c-f627-440e-b3d7-75cb13ea6825
# Optuna optimizes LightGBM with time budget 1542 seconds eval_metric auc (maximize)
# [I 2021-09-10 16:15:25,705] Trial 0 finished with value: 0.894486676158713 and parameters: {'learning_rate': 0.1, 'num_leaves': 1598, 'lambda_l1': 2.840098794801191e-06, 'lambda_l2': 3.0773599420974e-06, 'feature_fraction': 0.8613105322932351, 'bagging_fraction': 0.970697557159987, 'bagging_freq': 7, 'min_data_in_leaf': 36, 'extra_trees': False}. Best is trial 0 with value: 0.894486676158713.
# [I 2021-09-10 16:15:29,411] Trial 1 finished with value: 0.9000389044757905 and parameters: {'learning_rate': 0.0125, 'num_leaves': 30, 'lambda_l1': 0.09024841733204539, 'lambda_l2': 0.8785585624049705, 'feature_fraction': 0.5554201923798203, 'bagging_fraction': 0.7307773310574073, 'bagging_freq': 1, 'min_data_in_leaf': 37, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:32,516] Trial 2 finished with value: 0.8977490290023987 and parameters: {'learning_rate': 0.025, 'num_leaves': 1781, 'lambda_l1': 8.42482357544477e-05, 'lambda_l2': 0.1657023923779856, 'feature_fraction': 0.4006367785978634, 'bagging_fraction': 0.7929826868254444, 'bagging_freq': 5, 'min_data_in_leaf': 22, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:37,681] Trial 3 finished with value: 0.8972903005707065 and parameters: {'learning_rate': 0.0125, 'num_leaves': 1383, 'lambda_l1': 0.0022471032062799873, 'lambda_l2': 0.0006306544535695586, 'feature_fraction': 0.3303268443196031, 'bagging_fraction': 0.6930031616587092, 'bagging_freq': 3, 'min_data_in_leaf': 51, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:38,500] Trial 4 finished with value: 0.8999603421871956 and parameters: {'learning_rate': 0.1, 'num_leaves': 1620, 'lambda_l1': 8.48658950043472, 'lambda_l2': 4.2581000284199, 'feature_fraction': 0.854374902623789, 'bagging_fraction': 0.4996756748696664, 'bagging_freq': 5, 'min_data_in_leaf': 48, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:39,512] Trial 5 finished with value: 0.8980940842596687 and parameters: {'learning_rate': 0.05, 'num_leaves': 246, 'lambda_l1': 0.04433099767762488, 'lambda_l2': 0.0019307795983178134, 'feature_fraction': 0.6301427787405827, 'bagging_fraction': 0.37498877310697454, 'bagging_freq': 2, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:40,786] Trial 6 finished with value: 0.8971647892432084 and parameters: {'learning_rate': 0.1, 'num_leaves': 1881, 'lambda_l1': 0.004281836004345365, 'lambda_l2': 0.022593217631936842, 'feature_fraction': 0.4048836026912862, 'bagging_fraction': 0.8222443938563357, 'bagging_freq': 6, 'min_data_in_leaf': 64, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:43,699] Trial 7 finished with value: 0.8974082785280656 and parameters: {'learning_rate': 0.05, 'num_leaves': 1030, 'lambda_l1': 0.000679053100205625, 'lambda_l2': 0.23594925128557553, 'feature_fraction': 0.33998094723335825, 'bagging_fraction': 0.7685952268464016, 'bagging_freq': 6, 'min_data_in_leaf': 71, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:45,857] Trial 8 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:15:48,064] Trial 9 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:15:50,380] Trial 10 finished with value: 0.885208389160987 and parameters: {'learning_rate': 0.0125, 'num_leaves': 631, 'lambda_l1': 4.034106456637549e-08, 'lambda_l2': 2.00132355372712e-08, 'feature_fraction': 0.6646497644817525, 'bagging_fraction': 0.9635281141781353, 'bagging_freq': 1, 'min_data_in_leaf': 3, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:51,134] Trial 11 finished with value: 0.8996734014995711 and parameters: {'learning_rate': 0.1, 'num_leaves': 1070, 'lambda_l1': 8.240108101841239, 'lambda_l2': 9.185256451929346, 'feature_fraction': 0.9248796489072458, 'bagging_fraction': 0.5335150375873265, 'bagging_freq': 4, 'min_data_in_leaf': 32, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:52,198] Trial 12 finished with value: 0.8976092580814229 and parameters: {'learning_rate': 0.1, 'num_leaves': 653, 'lambda_l1': 0.3317614717519559, 'lambda_l2': 8.772015972662174, 'feature_fraction': 0.7539047100457399, 'bagging_fraction': 0.5145989055732224, 'bagging_freq': 1, 'min_data_in_leaf': 46, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:54,756] Trial 13 finished with value: 0.8962128941163303 and parameters: {'learning_rate': 0.0125, 'num_leaves': 1324, 'lambda_l1': 0.7435722055162166, 'lambda_l2': 0.5875462832100958, 'feature_fraction': 0.9990341977799744, 'bagging_fraction': 0.507774993559722, 'bagging_freq': 4, 'min_data_in_leaf': 16, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:15:55,439] Trial 14 finished with value: 0.8956784284098455 and parameters: {'learning_rate': 0.1, 'num_leaves': 628, 'lambda_l1': 0.011336852584652666, 'lambda_l2': 1.7030073328620516, 'feature_fraction': 0.5934294757490766, 'bagging_fraction': 0.3017515079918861, 'bagging_freq': 5, 'min_data_in_leaf': 52, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:16:00,787] Trial 15 finished with value: 0.8999637052988649 and parameters: {'learning_rate': 0.0125, 'num_leaves': 99, 'lambda_l1': 3.7873152953766204e-05, 'lambda_l2': 0.06709834144136902, 'feature_fraction': 0.7811716775123361, 'bagging_fraction': 0.6277675637585131, 'bagging_freq': 2, 'min_data_in_leaf': 37, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:16:05,639] Trial 16 finished with value: 0.8999545576351244 and parameters: {'learning_rate': 0.0125, 'num_leaves': 75, 'lambda_l1': 1.2720233218428937e-05, 'lambda_l2': 0.03248647695010859, 'feature_fraction': 0.7563267774652471, 'bagging_fraction': 0.6557916004123161, 'bagging_freq': 2, 'min_data_in_leaf': 30, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:16:07,153] Trial 17 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:16:10,894] Trial 18 pruned. Trial was pruned at iteration 602.
# [I 2021-09-10 16:16:14,723] Trial 19 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:16:16,136] Trial 20 finished with value: 0.8885784961025571 and parameters: {'learning_rate': 0.05, 'num_leaves': 448, 'lambda_l1': 0.00027682733533552654, 'lambda_l2': 1.2270917797834608e-08, 'feature_fraction': 0.7050999661458633, 'bagging_fraction': 0.8820500629520124, 'bagging_freq': 2, 'min_data_in_leaf': 2, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:16:17,891] Trial 21 finished with value: 0.8998916001846751 and parameters: {'learning_rate': 0.025, 'num_leaves': 2024, 'lambda_l1': 1.0904812077093975, 'lambda_l2': 1.6995986617381371, 'feature_fraction': 0.8300292616444471, 'bagging_fraction': 0.5661838905655132, 'bagging_freq': 4, 'min_data_in_leaf': 57, 'extra_trees': False}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:16:18,896] Trial 22 finished with value: 0.899175660972515 and parameters: {'learning_rate': 0.1, 'num_leaves': 1329, 'lambda_l1': 0.035369838093793925, 'lambda_l2': 1.1404970831015044, 'feature_fraction': 0.8248341110385286, 'bagging_fraction': 0.4555817842844865, 'bagging_freq': 1, 'min_data_in_leaf': 43, 'extra_trees': True}. Best is trial 1 with value: 0.9000389044757905.
# [I 2021-09-10 16:16:23,312] Trial 23 finished with value: 0.9017991571235011 and parameters: {'learning_rate': 0.0125, 'num_leaves': 144, 'lambda_l1': 8.82435693315119, 'lambda_l2': 0.007349180434785603, 'feature_fraction': 0.9072130663663704, 'bagging_fraction': 0.7031979780311114, 'bagging_freq': 5, 'min_data_in_leaf': 74, 'extra_trees': False}. Best is trial 23 with value: 0.9017991571235011.
# [I 2021-09-10 16:16:26,062] Trial 24 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:16:29,492] Trial 25 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:16:32,286] Trial 26 finished with value: 0.9004941352713467 and parameters: {'learning_rate': 0.0125, 'num_leaves': 480, 'lambda_l1': 2.1773049446300923, 'lambda_l2': 0.009200105323519083, 'feature_fraction': 0.9101838659344957, 'bagging_fraction': 0.7464147529260581, 'bagging_freq': 6, 'min_data_in_leaf': 58, 'extra_trees': False}. Best is trial 23 with value: 0.9017991571235011.
# [I 2021-09-10 16:16:35,323] Trial 27 finished with value: 0.8990253971431308 and parameters: {'learning_rate': 0.0125, 'num_leaves': 456, 'lambda_l1': 1.2641178520820078, 'lambda_l2': 0.007817100856087698, 'feature_fraction': 0.9085432710781094, 'bagging_fraction': 0.87675426258216, 'bagging_freq': 6, 'min_data_in_leaf': 57, 'extra_trees': False}. Best is trial 23 with value: 0.9017991571235011.
# [I 2021-09-10 16:16:38,714] Trial 28 finished with value: 0.9010330402852349 and parameters: {'learning_rate': 0.0125, 'num_leaves': 830, 'lambda_l1': 2.5106904397905785, 'lambda_l2': 0.00025947577844529613, 'feature_fraction': 0.9940781339374031, 'bagging_fraction': 0.7824064292636862, 'bagging_freq': 6, 'min_data_in_leaf': 83, 'extra_trees': False}. Best is trial 23 with value: 0.9017991571235011.
# [I 2021-09-10 16:16:42,869] Trial 29 finished with value: 0.9006326954721218 and parameters: {'learning_rate': 0.0125, 'num_leaves': 871, 'lambda_l1': 2.8112776225083635, 'lambda_l2': 2.963556613278445e-05, 'feature_fraction': 0.9858367952031494, 'bagging_fraction': 0.9631793939377586, 'bagging_freq': 7, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 23 with value: 0.9017991571235011.
# [I 2021-09-10 16:16:45,385] Trial 30 finished with value: 0.9024958593369128 and parameters: {'learning_rate': 0.025, 'num_leaves': 777, 'lambda_l1': 9.386305441054603, 'lambda_l2': 4.6542459877550784e-07, 'feature_fraction': 0.9722684425280165, 'bagging_fraction': 0.9805681092705182, 'bagging_freq': 7, 'min_data_in_leaf': 93, 'extra_trees': False}. Best is trial 30 with value: 0.9024958593369128.
# [I 2021-09-10 16:16:47,365] Trial 31 finished with value: 0.9006061941521676 and parameters: {'learning_rate': 0.025, 'num_leaves': 890, 'lambda_l1': 0.39398305810869294, 'lambda_l2': 2.944838244337625e-07, 'feature_fraction': 0.9777728354442707, 'bagging_fraction': 0.9777189488048321, 'bagging_freq': 7, 'min_data_in_leaf': 98, 'extra_trees': False}. Best is trial 30 with value: 0.9024958593369128.
# [I 2021-09-10 16:16:50,087] Trial 32 finished with value: 0.9020029616906605 and parameters: {'learning_rate': 0.025, 'num_leaves': 824, 'lambda_l1': 9.894127627308409, 'lambda_l2': 2.4702835065568115e-06, 'feature_fraction': 0.8789582408460601, 'bagging_fraction': 0.9330421319763234, 'bagging_freq': 7, 'min_data_in_leaf': 99, 'extra_trees': False}. Best is trial 30 with value: 0.9024958593369128.
# [I 2021-09-10 16:16:52,408] Trial 33 finished with value: 0.9022549260169243 and parameters: {'learning_rate': 0.025, 'num_leaves': 1124, 'lambda_l1': 8.065951402998419, 'lambda_l2': 3.655253537331145e-07, 'feature_fraction': 0.8854928311246894, 'bagging_fraction': 0.9040053460867734, 'bagging_freq': 7, 'min_data_in_leaf': 85, 'extra_trees': False}. Best is trial 30 with value: 0.9024958593369128.
# [I 2021-09-10 16:16:55,136] Trial 34 finished with value: 0.9019564162251574 and parameters: {'learning_rate': 0.025, 'num_leaves': 1209, 'lambda_l1': 9.91413376111077, 'lambda_l2': 5.305970773758119e-07, 'feature_fraction': 0.8784997685005728, 'bagging_fraction': 0.9060261322447385, 'bagging_freq': 7, 'min_data_in_leaf': 100, 'extra_trees': False}. Best is trial 30 with value: 0.9024958593369128.
# [I 2021-09-10 16:16:57,142] Trial 35 finished with value: 0.8989632468394821 and parameters: {'learning_rate': 0.025, 'num_leaves': 1165, 'lambda_l1': 0.5091714073508415, 'lambda_l2': 7.631980278015897e-07, 'feature_fraction': 0.8703485474657892, 'bagging_fraction': 0.9239370569966703, 'bagging_freq': 7, 'min_data_in_leaf': 100, 'extra_trees': False}. Best is trial 30 with value: 0.9024958593369128.
# [I 2021-09-10 16:17:00,006] Trial 36 finished with value: 0.9026968388902701 and parameters: {'learning_rate': 0.025, 'num_leaves': 1498, 'lambda_l1': 9.470604443954418, 'lambda_l2': 8.177234911263713e-08, 'feature_fraction': 0.8572616057199878, 'bagging_fraction': 0.9181725616196384, 'bagging_freq': 7, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:01,889] Trial 37 finished with value: 0.8994432301369244 and parameters: {'learning_rate': 0.025, 'num_leaves': 1498, 'lambda_l1': 0.034661381632553424, 'lambda_l2': 6.96452064241621e-08, 'feature_fraction': 0.8393476630071489, 'bagging_fraction': 0.8187106042401985, 'bagging_freq': 7, 'min_data_in_leaf': 92, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:03,746] Trial 38 finished with value: 0.8999136621972257 and parameters: {'learning_rate': 0.025, 'num_leaves': 1472, 'lambda_l1': 0.10996360081021792, 'lambda_l2': 2.654951749967604e-06, 'feature_fraction': 0.8762209786645578, 'bagging_fraction': 0.9919320535165419, 'bagging_freq': 6, 'min_data_in_leaf': 85, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:05,689] Trial 39 finished with value: 0.9011437539213882 and parameters: {'learning_rate': 0.025, 'num_leaves': 750, 'lambda_l1': 3.368566259836403, 'lambda_l2': 1.0149482856091565e-07, 'feature_fraction': 0.9445563158928146, 'bagging_fraction': 0.9230861949350536, 'bagging_freq': 7, 'min_data_in_leaf': 80, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:07,554] Trial 40 finished with value: 0.8994241276626427 and parameters: {'learning_rate': 0.025, 'num_leaves': 995, 'lambda_l1': 0.015422624856637828, 'lambda_l2': 5.791234529863994e-06, 'feature_fraction': 0.8023378619004252, 'bagging_fraction': 0.8247022362959772, 'bagging_freq': 6, 'min_data_in_leaf': 91, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:09,781] Trial 41 finished with value: 0.9020926895099974 and parameters: {'learning_rate': 0.025, 'num_leaves': 1191, 'lambda_l1': 7.459036329325065, 'lambda_l2': 1.0772871245663317e-06, 'feature_fraction': 0.8723717598903858, 'bagging_fraction': 0.9343126249082746, 'bagging_freq': 7, 'min_data_in_leaf': 94, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:11,819] Trial 42 finished with value: 0.9004619839237882 and parameters: {'learning_rate': 0.025, 'num_leaves': 1156, 'lambda_l1': 1.1962503152746786, 'lambda_l2': 1.7355801640249055e-06, 'feature_fraction': 0.9503477012266086, 'bagging_fraction': 0.9409399886955527, 'bagging_freq': 7, 'min_data_in_leaf': 88, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:14,244] Trial 43 finished with value: 0.9018813515726987 and parameters: {'learning_rate': 0.025, 'num_leaves': 1696, 'lambda_l1': 5.417389496090316, 'lambda_l2': 9.653210722497986e-08, 'feature_fraction': 0.8770492720705688, 'bagging_fraction': 0.9967226505248241, 'bagging_freq': 7, 'min_data_in_leaf': 91, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:16,348] Trial 44 finished with value: 0.9001971052487143 and parameters: {'learning_rate': 0.025, 'num_leaves': 959, 'lambda_l1': 1.755450457714131, 'lambda_l2': 3.37461169868831e-08, 'feature_fraction': 0.9435888154650424, 'bagging_fraction': 0.8550128188232002, 'bagging_freq': 6, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:18,362] Trial 45 finished with value: 0.8979633264779666 and parameters: {'learning_rate': 0.025, 'num_leaves': 1263, 'lambda_l1': 0.2246029811382029, 'lambda_l2': 2.683005217148583e-07, 'feature_fraction': 0.679409350590144, 'bagging_fraction': 0.947058147481095, 'bagging_freq': 7, 'min_data_in_leaf': 68, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:20,634] Trial 46 finished with value: 0.9015668333693859 and parameters: {'learning_rate': 0.025, 'num_leaves': 1057, 'lambda_l1': 4.8849189452313375, 'lambda_l2': 1.1627562868337489e-05, 'feature_fraction': 0.8441639038521079, 'bagging_fraction': 0.9002197767176126, 'bagging_freq': 7, 'min_data_in_leaf': 78, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:21,908] Trial 47 finished with value: 0.8999524052436562 and parameters: {'learning_rate': 0.05, 'num_leaves': 1479, 'lambda_l1': 0.8381565746628287, 'lambda_l2': 1.1820131760342595e-06, 'feature_fraction': 0.8964832051433675, 'bagging_fraction': 0.8412893313293017, 'bagging_freq': 6, 'min_data_in_leaf': 87, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:24,103] Trial 48 finished with value: 0.9008417464934853 and parameters: {'learning_rate': 0.025, 'num_leaves': 759, 'lambda_l1': 4.2120564815554165, 'lambda_l2': 3.7519033784015913e-07, 'feature_fraction': 0.762777570343327, 'bagging_fraction': 0.9025167306644665, 'bagging_freq': 5, 'min_data_in_leaf': 97, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:26,036] Trial 49 finished with value: 0.8995267698307897 and parameters: {'learning_rate': 0.025, 'num_leaves': 1646, 'lambda_l1': 0.0020199318893272507, 'lambda_l2': 4.347851470035528e-06, 'feature_fraction': 0.8088905710572626, 'bagging_fraction': 0.8013174786791935, 'bagging_freq': 7, 'min_data_in_leaf': 93, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:29,865] Trial 50 finished with value: 0.9017274555827115 and parameters: {'learning_rate': 0.025, 'num_leaves': 1124, 'lambda_l1': 9.280744934280072, 'lambda_l2': 3.943693750812907e-08, 'feature_fraction': 0.6274664325573283, 'bagging_fraction': 0.9338298036357212, 'bagging_freq': 6, 'min_data_in_leaf': 73, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:33,025] Trial 51 finished with value: 0.9019301839541369 and parameters: {'learning_rate': 0.025, 'num_leaves': 1224, 'lambda_l1': 9.64284258313251, 'lambda_l2': 6.202496787093589e-07, 'feature_fraction': 0.8902373078571926, 'bagging_fraction': 0.8986731810071228, 'bagging_freq': 7, 'min_data_in_leaf': 99, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:35,254] Trial 52 finished with value: 0.9007513460518145 and parameters: {'learning_rate': 0.025, 'num_leaves': 1399, 'lambda_l1': 2.1398990087479195, 'lambda_l2': 1.674321477439784e-05, 'feature_fraction': 0.8579058198741341, 'bagging_fraction': 0.9630931432087677, 'bagging_freq': 7, 'min_data_in_leaf': 84, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:37,500] Trial 53 finished with value: 0.9017628355174726 and parameters: {'learning_rate': 0.025, 'num_leaves': 1278, 'lambda_l1': 9.910142865571693, 'lambda_l2': 1.7667169128642187e-06, 'feature_fraction': 0.9710078616009352, 'bagging_fraction': 0.9112164547403481, 'bagging_freq': 7, 'min_data_in_leaf': 100, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:39,370] Trial 54 finished with value: 0.8992678102322538 and parameters: {'learning_rate': 0.025, 'num_leaves': 991, 'lambda_l1': 0.4020293300339404, 'lambda_l2': 1.0896580793482591e-07, 'feature_fraction': 0.9345854836951266, 'bagging_fraction': 0.9993210241325905, 'bagging_freq': 7, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:40,556] Trial 55 finished with value: 0.9001061667091764 and parameters: {'learning_rate': 0.05, 'num_leaves': 685, 'lambda_l1': 0.8317467544137368, 'lambda_l2': 3.0079647724915323e-07, 'feature_fraction': 0.9228153216217629, 'bagging_fraction': 0.8817551421184362, 'bagging_freq': 6, 'min_data_in_leaf': 88, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:42,749] Trial 56 finished with value: 0.9007148899213194 and parameters: {'learning_rate': 0.025, 'num_leaves': 562, 'lambda_l1': 4.636673755177497, 'lambda_l2': 5.8831507347759995e-05, 'feature_fraction': 0.7295984464489973, 'bagging_fraction': 0.9532150487281355, 'bagging_freq': 7, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:45,949] Trial 57 finished with value: 0.8980654305482465 and parameters: {'learning_rate': 0.025, 'num_leaves': 922, 'lambda_l1': 1.0662901941508101e-08, 'lambda_l2': 1.6636711470892037e-07, 'feature_fraction': 0.459813760252305, 'bagging_fraction': 0.8402977859341375, 'bagging_freq': 6, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:46,853] Trial 58 finished with value: 0.8984340275872016 and parameters: {'learning_rate': 0.1, 'num_leaves': 1091, 'lambda_l1': 0.06675994161062936, 'lambda_l2': 6.877801728606054e-07, 'feature_fraction': 0.8577054394007848, 'bagging_fraction': 0.8682122998974616, 'bagging_freq': 5, 'min_data_in_leaf': 82, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:49,089] Trial 59 finished with value: 0.8997476590052293 and parameters: {'learning_rate': 0.025, 'num_leaves': 1388, 'lambda_l1': 1.5678009191641333, 'lambda_l2': 1.4500906352477528e-08, 'feature_fraction': 0.8241205362703624, 'bagging_fraction': 0.970716772095583, 'bagging_freq': 7, 'min_data_in_leaf': 86, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:51,467] Trial 60 finished with value: 0.901113216867431 and parameters: {'learning_rate': 0.025, 'num_leaves': 1592, 'lambda_l1': 4.798204267859489, 'lambda_l2': 3.891883358828477e-08, 'feature_fraction': 0.7828034846240579, 'bagging_fraction': 0.942369181818976, 'bagging_freq': 7, 'min_data_in_leaf': 100, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:53,892] Trial 61 finished with value: 0.9017072769126958 and parameters: {'learning_rate': 0.025, 'num_leaves': 1287, 'lambda_l1': 7.06733791149851, 'lambda_l2': 6.33038451978198e-07, 'feature_fraction': 0.8948793857803377, 'bagging_fraction': 0.9014093402170518, 'bagging_freq': 7, 'min_data_in_leaf': 97, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:56,631] Trial 62 finished with value: 0.902358913429739 and parameters: {'learning_rate': 0.025, 'num_leaves': 1221, 'lambda_l1': 9.688856618572594, 'lambda_l2': 3.5294543626652034e-06, 'feature_fraction': 0.8878404450750965, 'bagging_fraction': 0.8942957316348136, 'bagging_freq': 7, 'min_data_in_leaf': 92, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:17:58,746] Trial 63 finished with value: 0.90065610272934 and parameters: {'learning_rate': 0.025, 'num_leaves': 1194, 'lambda_l1': 2.6233532245565576, 'lambda_l2': 4.614441704054332e-06, 'feature_fraction': 0.9710761206313377, 'bagging_fraction': 0.9235479812445528, 'bagging_freq': 7, 'min_data_in_leaf': 89, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:00,362] Trial 64 finished with value: 0.8989423955471324 and parameters: {'learning_rate': 0.025, 'num_leaves': 791, 'lambda_l1': 0.7314377238786077, 'lambda_l2': 2.236339617299044e-06, 'feature_fraction': 0.9227845124623832, 'bagging_fraction': 0.8541383253253928, 'bagging_freq': 6, 'min_data_in_leaf': 93, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:01,631] Trial 65 finished with value: 0.8994293741168469 and parameters: {'learning_rate': 0.05, 'num_leaves': 1056, 'lambda_l1': 1.3422240705908086e-06, 'lambda_l2': 1.9606621532606614e-07, 'feature_fraction': 0.9594706772362849, 'bagging_fraction': 0.8850210931643457, 'bagging_freq': 7, 'min_data_in_leaf': 93, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:03,943] Trial 66 finished with value: 0.8995137209575129 and parameters: {'learning_rate': 0.025, 'num_leaves': 1345, 'lambda_l1': 0.15063202240620802, 'lambda_l2': 0.0007575056928117772, 'feature_fraction': 0.8142493758814865, 'bagging_fraction': 0.9761539862284724, 'bagging_freq': 6, 'min_data_in_leaf': 84, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:04,663] Trial 67 finished with value: 0.8993311712561034 and parameters: {'learning_rate': 0.1, 'num_leaves': 1812, 'lambda_l1': 2.788230420915019, 'lambda_l2': 1.2946999896540921e-06, 'feature_fraction': 0.8803911887810578, 'bagging_fraction': 0.7525845675945109, 'bagging_freq': 7, 'min_data_in_leaf': 79, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:07,291] Trial 68 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:18:09,286] Trial 69 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:18:11,060] Trial 70 finished with value: 0.8983928631003693 and parameters: {'learning_rate': 0.025, 'num_leaves': 1201, 'lambda_l1': 0.5886625247744468, 'lambda_l2': 7.2102566867960975e-06, 'feature_fraction': 0.8471691428928333, 'bagging_fraction': 0.9230555892458712, 'bagging_freq': 7, 'min_data_in_leaf': 61, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:13,329] Trial 71 finished with value: 0.9013583204458895 and parameters: {'learning_rate': 0.025, 'num_leaves': 1192, 'lambda_l1': 9.059679469955695, 'lambda_l2': 9.5875236258205e-07, 'feature_fraction': 0.8912028207754272, 'bagging_fraction': 0.8968583615360268, 'bagging_freq': 7, 'min_data_in_leaf': 99, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:16,197] Trial 72 finished with value: 0.902685000737194 and parameters: {'learning_rate': 0.025, 'num_leaves': 1221, 'lambda_l1': 9.794643517633585, 'lambda_l2': 6.590392581084005e-08, 'feature_fraction': 0.922118537813552, 'bagging_fraction': 0.8725486054320072, 'bagging_freq': 7, 'min_data_in_leaf': 91, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:18,602] Trial 73 finished with value: 0.9012430329778659 and parameters: {'learning_rate': 0.025, 'num_leaves': 1091, 'lambda_l1': 4.313875623927126, 'lambda_l2': 2.8500895185357634e-08, 'feature_fraction': 0.9124177631749764, 'bagging_fraction': 0.8125131883311985, 'bagging_freq': 7, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:20,427] Trial 74 finished with value: 0.9016082669051516 and parameters: {'learning_rate': 0.025, 'num_leaves': 938, 'lambda_l1': 4.973943550979499, 'lambda_l2': 5.528812812434664e-08, 'feature_fraction': 0.8649460402856767, 'bagging_fraction': 0.9580361409843811, 'bagging_freq': 7, 'min_data_in_leaf': 86, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:22,098] Trial 75 finished with value: 0.9001108750655133 and parameters: {'learning_rate': 0.025, 'num_leaves': 1010, 'lambda_l1': 2.065804824844306, 'lambda_l2': 1.7289272669368808e-07, 'feature_fraction': 0.9256968973352087, 'bagging_fraction': 0.8659678304660889, 'bagging_freq': 7, 'min_data_in_leaf': 93, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:26,470] Trial 76 finished with value: 0.8999039764356183 and parameters: {'learning_rate': 0.025, 'num_leaves': 1333, 'lambda_l1': 0.00024010182745329268, 'lambda_l2': 1.1037054167334062e-08, 'feature_fraction': 0.9893065170750842, 'bagging_fraction': 0.9818407128634201, 'bagging_freq': 6, 'min_data_in_leaf': 97, 'extra_trees': True}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:28,593] Trial 77 finished with value: 0.901233481740725 and parameters: {'learning_rate': 0.025, 'num_leaves': 839, 'lambda_l1': 5.746110735684704, 'lambda_l2': 3.5563806415935566e-06, 'feature_fraction': 0.9575138969374646, 'bagging_fraction': 0.6837451447601203, 'bagging_freq': 7, 'min_data_in_leaf': 82, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:29,462] Trial 78 finished with value: 0.8998212438885534 and parameters: {'learning_rate': 0.1, 'num_leaves': 1246, 'lambda_l1': 1.4627155083288768, 'lambda_l2': 6.867631851156505e-08, 'feature_fraction': 0.9072045881720461, 'bagging_fraction': 0.8395975979269126, 'bagging_freq': 4, 'min_data_in_leaf': 69, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:30,592] Trial 79 finished with value: 0.9017444056655248 and parameters: {'learning_rate': 0.05, 'num_leaves': 689, 'lambda_l1': 3.320787813514549, 'lambda_l2': 1.3665991484549657e-07, 'feature_fraction': 0.8306625975560532, 'bagging_fraction': 0.918628597504912, 'bagging_freq': 7, 'min_data_in_leaf': 89, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:32,482] Trial 80 finished with value: 0.899193956299996 and parameters: {'learning_rate': 0.025, 'num_leaves': 1119, 'lambda_l1': 1.0565093654192614, 'lambda_l2': 2.2719376753069968e-08, 'feature_fraction': 0.8712134631548497, 'bagging_fraction': 0.8813976110918451, 'bagging_freq': 6, 'min_data_in_leaf': 93, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:35,216] Trial 81 finished with value: 0.9025278761600045 and parameters: {'learning_rate': 0.025, 'num_leaves': 1231, 'lambda_l1': 9.226676404321502, 'lambda_l2': 4.540242327191674e-07, 'feature_fraction': 0.8854295462733067, 'bagging_fraction': 0.9394557528755818, 'bagging_freq': 7, 'min_data_in_leaf': 100, 'extra_trees': False}. Best is trial 36 with value: 0.9026968388902701.
# [I 2021-09-10 16:18:37,847] Trial 82 finished with value: 0.9027101568124806 and parameters: {'learning_rate': 0.025, 'num_leaves': 1153, 'lambda_l1': 7.380893409434313, 'lambda_l2': 5.087934815564496e-07, 'feature_fraction': 0.9345396503174532, 'bagging_fraction': 0.9382197801319933, 'bagging_freq': 7, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:39,624] Trial 83 finished with value: 0.9005969119639603 and parameters: {'learning_rate': 0.025, 'num_leaves': 1148, 'lambda_l1': 3.1673574662688972, 'lambda_l2': 3.3291901475954944e-07, 'feature_fraction': 0.9987465674685233, 'bagging_fraction': 0.9329867968551896, 'bagging_freq': 7, 'min_data_in_leaf': 96, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:42,029] Trial 84 finished with value: 0.9022966286016235 and parameters: {'learning_rate': 0.025, 'num_leaves': 1946, 'lambda_l1': 7.209422956984511, 'lambda_l2': 1.3001134234638212e-06, 'feature_fraction': 0.9275246665704728, 'bagging_fraction': 0.9488878737717822, 'bagging_freq': 7, 'min_data_in_leaf': 91, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:44,648] Trial 85 finished with value: 0.9022198151310967 and parameters: {'learning_rate': 0.025, 'num_leaves': 1974, 'lambda_l1': 5.845959222561977, 'lambda_l2': 1.2605719444461582e-06, 'feature_fraction': 0.9633378775840941, 'bagging_fraction': 0.9470040392001051, 'bagging_freq': 7, 'min_data_in_leaf': 86, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:46,686] Trial 86 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:18:48,740] Trial 87 finished with value: 0.9001964326263803 and parameters: {'learning_rate': 0.025, 'num_leaves': 2044, 'lambda_l1': 1.8538471432360721, 'lambda_l2': 6.199555375304257e-08, 'feature_fraction': 0.9667996424019869, 'bagging_fraction': 0.9867223813644024, 'bagging_freq': 7, 'min_data_in_leaf': 86, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:50,946] Trial 88 finished with value: 0.9014958044509304 and parameters: {'learning_rate': 0.025, 'num_leaves': 1964, 'lambda_l1': 3.3068091680766734, 'lambda_l2': 1.4341303272900382e-06, 'feature_fraction': 0.9809460737527639, 'bagging_fraction': 0.9767221241684833, 'bagging_freq': 7, 'min_data_in_leaf': 91, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:52,665] Trial 89 finished with value: 0.8992959258458091 and parameters: {'learning_rate': 0.025, 'num_leaves': 1742, 'lambda_l1': 0.5003233244213529, 'lambda_l2': 1.0151091066749486e-07, 'feature_fraction': 0.950277754481665, 'bagging_fraction': 0.44477956971398014, 'bagging_freq': 6, 'min_data_in_leaf': 52, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:55,154] Trial 90 finished with value: 0.8998681929274568 and parameters: {'learning_rate': 0.025, 'num_leaves': 1865, 'lambda_l1': 1.789054494251396e-07, 'lambda_l2': 1.1303510574457664e-05, 'feature_fraction': 0.9303748780558797, 'bagging_fraction': 0.9505015732638231, 'bagging_freq': 3, 'min_data_in_leaf': 84, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:57,545] Trial 91 finished with value: 0.9023391383331235 and parameters: {'learning_rate': 0.025, 'num_leaves': 1759, 'lambda_l1': 6.641768536200679, 'lambda_l2': 9.434637689573251e-07, 'feature_fraction': 0.9055430165174783, 'bagging_fraction': 0.9433886952904217, 'bagging_freq': 7, 'min_data_in_leaf': 87, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:18:59,749] Trial 92 finished with value: 0.9018607693292826 and parameters: {'learning_rate': 0.025, 'num_leaves': 1979, 'lambda_l1': 5.987169306761636, 'lambda_l2': 4.836817937192496e-07, 'feature_fraction': 0.9090262371497319, 'bagging_fraction': 0.9110172748181466, 'bagging_freq': 7, 'min_data_in_leaf': 87, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:02,236] Trial 93 finished with value: 0.9020008092991921 and parameters: {'learning_rate': 0.025, 'num_leaves': 1761, 'lambda_l1': 6.737322157767057, 'lambda_l2': 2.380515078538079e-06, 'feature_fraction': 0.8945883121655903, 'bagging_fraction': 0.9649003902370856, 'bagging_freq': 7, 'min_data_in_leaf': 80, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:04,148] Trial 94 finished with value: 0.9005874952512863 and parameters: {'learning_rate': 0.025, 'num_leaves': 1944, 'lambda_l1': 2.1556150161773298, 'lambda_l2': 7.959236562846754e-07, 'feature_fraction': 0.9435145353586883, 'bagging_fraction': 0.8902502736067132, 'bagging_freq': 7, 'min_data_in_leaf': 91, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:07,200] Trial 95 finished with value: 0.9012145137909102 and parameters: {'learning_rate': 0.025, 'num_leaves': 1685, 'lambda_l1': 3.4267427562981596, 'lambda_l2': 2.395996957527671e-07, 'feature_fraction': 0.9166445699777583, 'bagging_fraction': 0.9401040058193023, 'bagging_freq': 7, 'min_data_in_leaf': 88, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:10,396] Trial 96 finished with value: 0.9021933138111428 and parameters: {'learning_rate': 0.025, 'num_leaves': 1899, 'lambda_l1': 6.104407574502153, 'lambda_l2': 3.9809552637122703e-07, 'feature_fraction': 0.9586516743878774, 'bagging_fraction': 0.9129460090647472, 'bagging_freq': 7, 'min_data_in_leaf': 82, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:12,476] Trial 97 finished with value: 0.9000924452135656 and parameters: {'learning_rate': 0.025, 'num_leaves': 1826, 'lambda_l1': 1.0696377801882984, 'lambda_l2': 9.544944456098862e-07, 'feature_fraction': 0.9347728767710939, 'bagging_fraction': 0.9849320660113045, 'bagging_freq': 7, 'min_data_in_leaf': 97, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:15,822] Trial 98 finished with value: 0.902553570333158 and parameters: {'learning_rate': 0.025, 'num_leaves': 1448, 'lambda_l1': 9.706111688387509, 'lambda_l2': 3.637037930645437e-06, 'feature_fraction': 0.8465505005963545, 'bagging_fraction': 0.8682509872306545, 'bagging_freq': 7, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:17,306] Trial 99 finished with value: 0.8978497878280112 and parameters: {'learning_rate': 0.1, 'num_leaves': 1516, 'lambda_l1': 9.521383674693897, 'lambda_l2': 7.280290101400361e-05, 'feature_fraction': 0.8495781480163198, 'bagging_fraction': 0.8534057725343643, 'bagging_freq': 6, 'min_data_in_leaf': 29, 'extra_trees': True}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:18,944] Trial 100 finished with value: 0.8870041562679253 and parameters: {'learning_rate': 0.05, 'num_leaves': 1632, 'lambda_l1': 7.153552852068662e-06, 'lambda_l2': 5.208901042785259e-06, 'feature_fraction': 0.9020765372647374, 'bagging_fraction': 0.8682362744440243, 'bagging_freq': 7, 'min_data_in_leaf': 13, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:21,409] Trial 101 finished with value: 0.9007288804658636 and parameters: {'learning_rate': 0.025, 'num_leaves': 1279, 'lambda_l1': 3.810499149290405, 'lambda_l2': 2.562088680370115e-06, 'feature_fraction': 0.8859217837446015, 'bagging_fraction': 0.9381986067071919, 'bagging_freq': 7, 'min_data_in_leaf': 94, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:23,604] Trial 102 finished with value: 0.9004037348296758 and parameters: {'learning_rate': 0.025, 'num_leaves': 1368, 'lambda_l1': 2.165711161744552, 'lambda_l2': 1.4012431391137118e-06, 'feature_fraction': 0.9726702693503345, 'bagging_fraction': 0.9675569590111046, 'bagging_freq': 7, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:25,707] Trial 103 finished with value: 0.9017091602552306 and parameters: {'learning_rate': 0.025, 'num_leaves': 1538, 'lambda_l1': 5.053373745311696, 'lambda_l2': 6.589548270855535e-07, 'feature_fraction': 0.9200277648669187, 'bagging_fraction': 0.927913571456513, 'bagging_freq': 7, 'min_data_in_leaf': 85, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:27,975] Trial 104 finished with value: 0.9022272139767691 and parameters: {'learning_rate': 0.025, 'num_leaves': 1306, 'lambda_l1': 7.458917730218958, 'lambda_l2': 2.644377394168798e-07, 'feature_fraction': 0.8378630264389808, 'bagging_fraction': 0.9971512136160114, 'bagging_freq': 7, 'min_data_in_leaf': 92, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:30,874] Trial 105 finished with value: 0.9024588651085504 and parameters: {'learning_rate': 0.025, 'num_leaves': 1439, 'lambda_l1': 9.65424074880524, 'lambda_l2': 1.3407336639012079e-07, 'feature_fraction': 0.8638489934111958, 'bagging_fraction': 0.9977656533866979, 'bagging_freq': 7, 'min_data_in_leaf': 92, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:32,853] Trial 106 finished with value: 0.8995034970980383 and parameters: {'learning_rate': 0.025, 'num_leaves': 1441, 'lambda_l1': 0.0035387295368586656, 'lambda_l2': 1.428359414048319e-07, 'feature_fraction': 0.8627308501505738, 'bagging_fraction': 0.8889328886613005, 'bagging_freq': 7, 'min_data_in_leaf': 98, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:34,993] Trial 107 finished with value: 0.9003415845260272 and parameters: {'learning_rate': 0.025, 'num_leaves': 1589, 'lambda_l1': 2.706390286479434, 'lambda_l2': 1.9462269756495854e-08, 'feature_fraction': 0.7972116086047732, 'bagging_fraction': 0.5734010959325385, 'bagging_freq': 7, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:36,869] Trial 108 finished with value: 0.8971720535644141 and parameters: {'learning_rate': 0.025, 'num_leaves': 1472, 'lambda_l1': 1.3008428334132824, 'lambda_l2': 7.542720212648806e-08, 'feature_fraction': 0.5776774995840189, 'bagging_fraction': 0.9104134616423786, 'bagging_freq': 6, 'min_data_in_leaf': 90, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:39,482] Trial 109 finished with value: 0.9023014714824273 and parameters: {'learning_rate': 0.025, 'num_leaves': 1236, 'lambda_l1': 9.142152633125423, 'lambda_l2': 4.0475748406431465e-08, 'feature_fraction': 0.7773817252487537, 'bagging_fraction': 0.9613322955613459, 'bagging_freq': 7, 'min_data_in_leaf': 88, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:41,690] Trial 110 finished with value: 0.9012089982877725 and parameters: {'learning_rate': 0.025, 'num_leaves': 1444, 'lambda_l1': 3.954009245227554, 'lambda_l2': 5.013908206535094e-08, 'feature_fraction': 0.8262460891135571, 'bagging_fraction': 0.9592325460931558, 'bagging_freq': 7, 'min_data_in_leaf': 48, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:44,045] Trial 111 finished with value: 0.9026045551060646 and parameters: {'learning_rate': 0.025, 'num_leaves': 1226, 'lambda_l1': 9.871517870199318, 'lambda_l2': 4.2210854117149957e-07, 'feature_fraction': 0.7718600851447366, 'bagging_fraction': 0.9751306157579559, 'bagging_freq': 7, 'min_data_in_leaf': 89, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:47,305] Trial 112 finished with value: 0.902437341193867 and parameters: {'learning_rate': 0.025, 'num_leaves': 1246, 'lambda_l1': 9.7616737666519, 'lambda_l2': 1.0493315420519256e-07, 'feature_fraction': 0.7682701425783377, 'bagging_fraction': 0.972692295167939, 'bagging_freq': 7, 'min_data_in_leaf': 88, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:51,067] Trial 113 finished with value: 0.9023730384987501 and parameters: {'learning_rate': 0.025, 'num_leaves': 1253, 'lambda_l1': 9.557021648223257, 'lambda_l2': 1.122642519089092e-07, 'feature_fraction': 0.7425820250226481, 'bagging_fraction': 0.9743900389524726, 'bagging_freq': 7, 'min_data_in_leaf': 89, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:53,255] Trial 114 finished with value: 0.9011997160995653 and parameters: {'learning_rate': 0.025, 'num_leaves': 1358, 'lambda_l1': 4.461297664162854, 'lambda_l2': 1.2943154080101192e-07, 'feature_fraction': 0.7653192322780359, 'bagging_fraction': 0.9865811172504084, 'bagging_freq': 7, 'min_data_in_leaf': 94, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:19:55,486] Trial 115 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:19:58,870] Trial 116 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:20:01,177] Trial 117 finished with value: 0.8992400981920988 and parameters: {'learning_rate': 0.025, 'num_leaves': 1245, 'lambda_l1': 2.86385659016771, 'lambda_l2': 4.646443190078581e-07, 'feature_fraction': 0.6542884636454375, 'bagging_fraction': 0.9755905591471601, 'bagging_freq': 7, 'min_data_in_leaf': 98, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:03,240] Trial 118 finished with value: 0.8994936768119639 and parameters: {'learning_rate': 0.025, 'num_leaves': 1416, 'lambda_l1': 0.8157109825522284, 'lambda_l2': 2.477093896469086e-08, 'feature_fraction': 0.7325123683997992, 'bagging_fraction': 0.9261873159337248, 'bagging_freq': 7, 'min_data_in_leaf': 92, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:05,675] Trial 119 finished with value: 0.901152094438328 and parameters: {'learning_rate': 0.025, 'num_leaves': 1036, 'lambda_l1': 4.542654887025363, 'lambda_l2': 2.8935244783909955e-07, 'feature_fraction': 0.8104520908622518, 'bagging_fraction': 0.9409185253429346, 'bagging_freq': 7, 'min_data_in_leaf': 95, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:07,753] Trial 120 pruned. Trial was pruned at iteration 500.
# [I 2021-09-10 16:20:10,647] Trial 121 finished with value: 0.902217931788562 and parameters: {'learning_rate': 0.025, 'num_leaves': 1230, 'lambda_l1': 9.161744258041834, 'lambda_l2': 4.153292143658405e-08, 'feature_fraction': 0.7458488723260159, 'bagging_fraction': 0.9640481205621183, 'bagging_freq': 7, 'min_data_in_leaf': 88, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:13,407] Trial 122 finished with value: 0.9024205256355206 and parameters: {'learning_rate': 0.025, 'num_leaves': 1317, 'lambda_l1': 9.581741140260334, 'lambda_l2': 3.8705985232613486e-08, 'feature_fraction': 0.7901513847949997, 'bagging_fraction': 0.9547230189067647, 'bagging_freq': 7, 'min_data_in_leaf': 89, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:16,159] Trial 123 finished with value: 0.90237303849875 and parameters: {'learning_rate': 0.025, 'num_leaves': 1385, 'lambda_l1': 9.882162067333477, 'lambda_l2': 1.7659176867309694e-08, 'feature_fraction': 0.7867730767739994, 'bagging_fraction': 0.9901953655203167, 'bagging_freq': 7, 'min_data_in_leaf': 5, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:18,462] Trial 124 finished with value: 0.9001477347694089 and parameters: {'learning_rate': 0.025, 'num_leaves': 1325, 'lambda_l1': 3.4799000993942775, 'lambda_l2': 1.6933036721042062e-08, 'feature_fraction': 0.779792892739141, 'bagging_fraction': 0.9907583808402209, 'bagging_freq': 7, 'min_data_in_leaf': 41, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:20,846] Trial 125 finished with value: 0.8773165113178125 and parameters: {'learning_rate': 0.025, 'num_leaves': 1386, 'lambda_l1': 0.0006407049579475775, 'lambda_l2': 1.028938764954995e-08, 'feature_fraction': 0.7688193566460031, 'bagging_fraction': 0.9724345446149436, 'bagging_freq': 7, 'min_data_in_leaf': 7, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# [I 2021-09-10 16:20:21,617] Trial 126 finished with value: 0.901961259105961 and parameters: {'learning_rate': 0.1, 'num_leaves': 1270, 'lambda_l1': 9.821815684401333, 'lambda_l2': 2.7496665813824852e-08, 'feature_fraction': 0.7863847455728155, 'bagging_fraction': 0.9990999013634861, 'bagging_freq': 7, 'min_data_in_leaf': 18, 'extra_trees': False}. Best is trial 82 with value: 0.9027101568124806.
# ...
# [I 2021-09-10 18:12:20,540] Trial 17 finished with value: 0.8461391208987525 and parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_split': 23, 'min_samples_leaf': 19, 'max_features': 0.10649567519452202}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:12:54,779] Trial 18 finished with value: 0.8824008635394571 and parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 45, 'min_samples_leaf': 42, 'max_features': 0.42734298243306357}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:13:21,224] Trial 19 finished with value: 0.8939348567960146 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 14, 'max_features': 0.21634590256804312}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:13:34,720] Trial 20 finished with value: 0.8790759568187223 and parameters: {'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 46, 'min_samples_leaf': 62, 'max_features': 0.11660794035551822}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:14:07,056] Trial 21 finished with value: 0.8957034499606651 and parameters: {'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 34, 'min_samples_leaf': 3, 'max_features': 0.30425889548883345}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:14:52,034] Trial 22 finished with value: 0.8960572493082753 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 24, 'min_samples_leaf': 2, 'max_features': 0.4289442916188491}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:15:33,404] Trial 23 finished with value: 0.8893542987024308 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 28, 'max_features': 0.45773273154038774}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:16:02,038] Trial 24 finished with value: 0.8919638043088725 and parameters: {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 29, 'min_samples_leaf': 14, 'max_features': 0.28391033410579414}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:16:44,513] Trial 25 finished with value: 0.8855702599766035 and parameters: {'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 0.6530050792631599}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:17:04,433] Trial 26 finished with value: 0.893774907205023 and parameters: {'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 46, 'min_samples_leaf': 1, 'max_features': 0.1782292278316916}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:17:47,997] Trial 27 finished with value: 0.8899171490714045 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 71, 'min_samples_leaf': 26, 'max_features': 0.4943113871697977}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:18:19,039] Trial 28 finished with value: 0.894846529107328 and parameters: {'criterion': 'entropy', 'max_depth': 28, 'min_samples_split': 22, 'min_samples_leaf': 12, 'max_features': 0.24903978875085656}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:18:43,069] Trial 29 finished with value: 0.8591916263362316 and parameters: {'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 44, 'min_samples_leaf': 97, 'max_features': 0.32507055320701184}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:18:52,964] Trial 30 finished with value: 0.8710935440094103 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 90, 'max_features': 0.08448818617859338}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:19:35,039] Trial 31 finished with value: 0.895964696475136 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 36, 'min_samples_leaf': 1, 'max_features': 0.39423372522905004}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:20:15,408] Trial 32 finished with value: 0.8950519479680887 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 31, 'min_samples_leaf': 10, 'max_features': 0.3837505977965596}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:21:11,604] Trial 33 finished with value: 0.8955223800283901 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 40, 'min_samples_leaf': 1, 'max_features': 0.5330489704196348}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:21:40,242] Trial 34 finished with value: 0.8920170759977142 and parameters: {'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 50, 'min_samples_leaf': 17, 'max_features': 0.273663595314508}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:22:24,714] Trial 35 finished with value: 0.8951676390095125 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 25, 'min_samples_leaf': 9, 'max_features': 0.4378436563096883}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:23:07,980] Trial 36 finished with value: 0.8850507264859303 and parameters: {'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 63, 'min_samples_leaf': 34, 'max_features': 0.6126930381284297}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:23:33,601] Trial 37 finished with value: 0.8660116132281674 and parameters: {'criterion': 'gini', 'max_depth': 32, 'min_samples_split': 41, 'min_samples_leaf': 78, 'max_features': 0.35068155607148604}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:23:52,623] Trial 38 finished with value: 0.8838217109575021 and parameters: {'criterion': 'entropy', 'max_depth': 29, 'min_samples_split': 51, 'min_samples_leaf': 43, 'max_features': 0.1679294540078234}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:24:04,818] Trial 39 finished with value: 0.8930343500154435 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 0.06447841325384657}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:24:43,487] Trial 40 finished with value: 0.8904918375934543 and parameters: {'criterion': 'entropy', 'max_depth': 14, 'min_samples_split': 59, 'min_samples_leaf': 6, 'max_features': 0.4903263500600523}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:25:25,951] Trial 41 finished with value: 0.8960279229745189 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 34, 'min_samples_leaf': 1, 'max_features': 0.39576860657529084}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:26:03,812] Trial 42 finished with value: 0.8947421381211129 and parameters: {'criterion': 'entropy', 'max_depth': 18, 'min_samples_split': 32, 'min_samples_leaf': 6, 'max_features': 0.3898897416245539}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:26:31,354] Trial 43 finished with value: 0.8938503754308817 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 29, 'min_samples_leaf': 14, 'max_features': 0.23727004498886564}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:27:04,096] Trial 44 finished with value: 0.8960322277574555 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 40, 'min_samples_leaf': 1, 'max_features': 0.29347460394697533}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:27:21,120] Trial 45 finished with value: 0.8867828635200856 and parameters: {'criterion': 'gini', 'max_depth': 16, 'min_samples_split': 41, 'min_samples_leaf': 24, 'max_features': 0.16153684574355634}. Best is trial 11 with value: 0.8961991726207195.
# [I 2021-09-10 18:27:57,078] Trial 46 finished with value: 0.8964500607512491 and parameters: {'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 55, 'min_samples_leaf': 6, 'max_features': 0.3126473143045717}. Best is trial 46 with value: 0.8964500607512491.
# [I 2021-09-10 18:28:30,726] Trial 47 finished with value: 0.8880717424362272 and parameters: {'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 70, 'min_samples_leaf': 30, 'max_features': 0.3427393016545303}. Best is trial 46 with value: 0.8964500607512491.
# [I 2021-09-10 18:29:55,183] Trial 48 finished with value: 0.8920430392198011 and parameters: {'criterion': 'entropy', 'max_depth': 28, 'min_samples_split': 54, 'min_samples_leaf': 15, 'max_features': 0.9589525932771776}. Best is trial 46 with value: 0.8964500607512491.
# 5_Optuna_RandomForest auc 0.896113 trained in 88.5 seconds
# [I 2021-09-10 18:31:27,803] A new study created in memory with name: no-name-183a91bc-6038-4c3d-b494-e4db62d4f5c5
# Optuna optimizes Extra Trees with time budget 1542 seconds eval_metric auc (maximize)
# [I 2021-09-10 18:31:54,928] Trial 0 finished with value: 0.8414419300924775 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 79, 'min_samples_leaf': 78, 'max_features': 0.27986667922981523}. Best is trial 0 with value: 0.8414419300924775.
# [I 2021-09-10 18:32:56,732] Trial 1 finished with value: 0.8691761667845102 and parameters: {'criterion': 'entropy', 'max_depth': 31, 'min_samples_split': 88, 'min_samples_leaf': 36, 'max_features': 0.5059851742682241}. Best is trial 1 with value: 0.8691761667845102.
# [I 2021-09-10 18:33:00,906] Trial 2 finished with value: 0.8025043612832128 and parameters: {'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 57, 'min_samples_leaf': 51, 'max_features': 0.023630765094775418}. Best is trial 1 with value: 0.8691761667845102.
# [I 2021-09-10 18:33:34,353] Trial 3 finished with value: 0.8513702393136453 and parameters: {'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 62, 'min_samples_leaf': 8, 'max_features': 0.3751357659419548}. Best is trial 1 with value: 0.8691761667845102.
# [I 2021-09-10 18:34:22,822] Trial 4 finished with value: 0.852577192829523 and parameters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 80, 'min_samples_leaf': 32, 'max_features': 0.5724176660998085}. Best is trial 1 with value: 0.8691761667845102.
# [I 2021-09-10 18:35:36,552] Trial 5 finished with value: 0.8634867235113253 and parameters: {'criterion': 'gini', 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 71, 'max_features': 0.7075354951076768}. Best is trial 1 with value: 0.8691761667845102.
# [I 2021-09-10 18:35:58,782] Trial 6 finished with value: 0.847706599985579 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 92, 'min_samples_leaf': 6, 'max_features': 0.19244421297567552}. Best is trial 1 with value: 0.8691761667845102.
# [I 2021-09-10 18:37:00,284] Trial 7 finished with value: 0.8717297102127747 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 54, 'min_samples_leaf': 5, 'max_features': 0.5658187492627639}. Best is trial 7 with value: 0.8717297102127747.
# [I 2021-09-10 18:37:03,860] Trial 8 finished with value: 0.7946415407248608 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 62, 'min_samples_leaf': 57, 'max_features': 0.016696421370102764}. Best is trial 7 with value: 0.8717297102127747.
# [I 2021-09-10 18:38:23,084] Trial 9 finished with value: 0.8587459467778162 and parameters: {'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 100, 'min_samples_leaf': 96, 'max_features': 0.7940444939387233}. Best is trial 7 with value: 0.8717297102127747.
# [I 2021-09-10 18:40:03,152] Trial 10 finished with value: 0.8731145050737248 and parameters: {'criterion': 'gini', 'max_depth': 22, 'min_samples_split': 27, 'min_samples_leaf': 23, 'max_features': 0.9732616534433121}. Best is trial 10 with value: 0.8731145050737248.
# [I 2021-09-10 18:41:43,226] Trial 11 finished with value: 0.8732170127174049 and parameters: {'criterion': 'gini', 'max_depth': 22, 'min_samples_split': 27, 'min_samples_leaf': 23, 'max_features': 0.9834110627368414}. Best is trial 11 with value: 0.8732170127174049.
# [I 2021-09-10 18:43:23,309] Trial 12 finished with value: 0.8728906563610164 and parameters: {'criterion': 'gini', 'max_depth': 23, 'min_samples_split': 23, 'min_samples_leaf': 27, 'max_features': 0.96901170834279}. Best is trial 11 with value: 0.8732170127174049.
# [I 2021-09-10 18:45:13,523] Trial 13 finished with value: 0.8754448724116147 and parameters: {'criterion': 'gini', 'max_depth': 32, 'min_samples_split': 33, 'min_samples_leaf': 26, 'max_features': 0.9882581194666676}. Best is trial 13 with value: 0.8754448724116147.
# [I 2021-09-10 18:46:43,978] Trial 14 finished with value: 0.8705227566968969 and parameters: {'criterion': 'gini', 'max_depth': 32, 'min_samples_split': 36, 'min_samples_leaf': 41, 'max_features': 0.8164787783791287}. Best is trial 13 with value: 0.8754448724116147.
# [I 2021-09-10 18:47:21,230] Trial 15 finished with value: 0.8148847824846991 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 18, 'max_features': 0.851716500309868}. Best is trial 13 with value: 0.8754448724116147.
# [I 2021-09-10 18:49:12,255] Trial 16 finished with value: 0.877211716758197 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_split': 41, 'min_samples_leaf': 18, 'max_features': 0.9973668213708834}. Best is trial 16 with value: 0.877211716758197.
# [I 2021-09-10 18:50:28,993] Trial 17 finished with value: 0.8693974595323499 and parameters: {'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 41, 'min_samples_leaf': 43, 'max_features': 0.7070039053761459}. Best is trial 16 with value: 0.877211716758197.
# [I 2021-09-10 18:52:08,767] Trial 18 finished with value: 0.87860431403822 and parameters: {'criterion': 'gini', 'max_depth': 28, 'min_samples_split': 43, 'min_samples_leaf': 13, 'max_features': 0.8782000191854304}. Best is trial 18 with value: 0.87860431403822.
# [I 2021-09-10 18:53:27,206] Trial 19 finished with value: 0.8757463417416507 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_split': 44, 'min_samples_leaf': 14, 'max_features': 0.6905142199029579}. Best is trial 18 with value: 0.87860431403822.
# [I 2021-09-10 18:54:51,453] Trial 20 finished with value: 0.8727711986345229 and parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 72, 'min_samples_leaf': 2, 'max_features': 0.8759051992197466}. Best is trial 18 with value: 0.87860431403822.
# [I 2021-09-10 18:56:12,496] Trial 21 finished with value: 0.8759911762711756 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_split': 44, 'min_samples_leaf': 15, 'max_features': 0.7029783438653477}. Best is trial 18 with value: 0.87860431403822.
# [I 2021-09-10 18:57:51,589] Trial 22 finished with value: 0.8780542434935896 and parameters: {'criterion': 'gini', 'max_depth': 28, 'min_samples_split': 48, 'min_samples_leaf': 14, 'max_features': 0.874705103340748}. Best is trial 18 with value: 0.87860431403822.
# 6_Optuna_ExtraTrees auc 0.879138 trained in 103.83 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble auc 0.904018 trained in 4.68 seconds
# * Step stack will try to check up to 6 models
# 3_Optuna_CatBoost_Stacked auc 0.904975 trained in 15.49 seconds
# 2_Optuna_Xgboost_Stacked auc 0.896752 trained in 15.52 seconds
# 1_Optuna_LightGBM_Stacked auc 0.904322 trained in 12.52 seconds
# 5_Optuna_RandomForest_Stacked auc 0.905996 trained in 107.08 seconds
# 6_Optuna_ExtraTrees_Stacked auc 0.904128 trained in 109.33 seconds
# 4_Optuna_NeuralNetwork_Stacked auc 0.897783 trained in 48.93 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked auc 0.90659 trained in 6.75 seconds
# AutoML fit time: 10192.69 seconds
# AutoML best model: Ensemble_Stacked
# ------------------------------------
# Running time: 169.89 minutes.
# Start time: 2021-09-10, 16:15:22
# End time: 2021-09-10, 19:05:16
# ------------------------------------

# %% [markdown]
# ### Assessing the outcomes

# %%
# compete_model = models['Compete']
optuna_model = models['Optuna']

# %% [markdown]
# #### ML pipeline

# %% [markdown]
# Constructed pipelines (Compete mode)

# %%
# Dataframe with tested models:
compete_leaderboard = compete_model.get_leaderboard()

print(f'Number of tested pipelines: {len(compete_leaderboard)}.')
compete_leaderboard.sort_values('metric_value', ascending=True)

# %%
# Information about tested models and the best one:
compete_model.report()

# %% [markdown]
# Final pipeline (Compete mode)

# %%
# Best model:
best_model_compete = compete_leaderboard.sort_values('metric_value', ascending=True)['name'].iloc[0]
display(Markdown(f'../Datasets/Outcomes/mljar/Compete/{estimation_id}/{best_model_compete}/README.md'))

# %% [markdown]
# Constructed pipelines (Optuna mode)

# %%
# Dataframe with tested models:
optuna_leaderboard = optuna_model.get_leaderboard()

print(f'Number of tested pipelines: {len(optuna_leaderboard)}.')
optuna_leaderboard
# Out:
# Number of tested pipelines: 14.
#                               name      model_type  ... metric_value  train_time
# 0                1_Optuna_LightGBM        LightGBM  ...    -0.900586       16.67
# 1                 2_Optuna_Xgboost         Xgboost  ...    -0.902536       34.46
# 2                3_Optuna_CatBoost        CatBoost  ...    -0.903371       22.27
# 3           4_Optuna_NeuralNetwork  Neural Network  ...    -0.869787       57.40
# 4            5_Optuna_RandomForest   Random Forest  ...    -0.896113       90.03
# 5              6_Optuna_ExtraTrees     Extra Trees  ...    -0.879138      105.29
# 6                         Ensemble        Ensemble  ...    -0.904018        4.68
# 7        3_Optuna_CatBoost_Stacked        CatBoost  ...    -0.904975       17.02
# 8         2_Optuna_Xgboost_Stacked         Xgboost  ...    -0.896752       17.08
# 9        1_Optuna_LightGBM_Stacked        LightGBM  ...    -0.904322       13.96
# 10   5_Optuna_RandomForest_Stacked   Random Forest  ...    -0.905996      108.51
# 11     6_Optuna_ExtraTrees_Stacked     Extra Trees  ...    -0.904128      110.79
# 12  4_Optuna_NeuralNetwork_Stacked  Neural Network  ...    -0.897783       50.39
# 13                Ensemble_Stacked        Ensemble  ...    -0.906590        6.75
#
# [14 rows x 5 columns]

# %%
# Information about tested models and the best one:
optuna_model.report()

# %% [markdown]
# Final pipeline (Optuna mode)

# %%
# Best model:
best_model_optuna = optuna_leaderboard.sort_values('metric_value', ascending=True)['name'].iloc[0]
display(Markdown(f'../Datasets/Outcomes/mljar/Optuna/{estimation_id}/{best_model_compete}/README.md'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-521abe5b1f7a> in <module>()
#       1 # Best model:
#       2 best_model_optuna = optuna_leaderboard.sort_values('metric_value', ascending=True)['name'].iloc[0]
# ----> 3 display(Markdown(f'../Datasets/Outcomes/mljar/Optuna/{estimation_id}/{best_model_compete}/README.md'))
#
# NameError: name 'best_model_compete' is not defined

# %% [markdown]
# #### Model evaluation

# %%
perf_metrics = {}

for model in models:
  # Predictions for hold-out data:
  y_hat = [p[1] for p in models[model].predict_proba(df_test.drop(drop_vars, axis=1))]

  # Performance metrics of the best model:
  perf_metrics[model] = {
      f'test_roc_auc': roc_auc_score(df_test['class'], y_hat),
      f'test_avg_prec': average_precision_score(df_test['class'], y_hat),
      f'test_brier': brier_score_loss(df_test['class'], y_hat),
      f'test_acc': accuracy_score(df_test['class'], [1 if p > 0.5 else 0 for p in y_hat]),
      f'test_mcc': matthews_corrcoef(df_test['class'], [1 if p > 0.5 else 0 for p in y_hat])
  }

  print(f'{models[model].mode} mode:\n')
  print(f'Test ROC-AUC: {perf_metrics[model]["test_roc_auc"]:.4f}.')
  print(f'Test average-precision score: {perf_metrics[model]["test_avg_prec"]:.4f}.')
  print(f'Test Brier score: {perf_metrics[model]["test_brier"]:.4f}.')
  print(f'Test accuracy: {perf_metrics[model]["test_acc"]:.4f}.')
  print(f'Test MCC: {perf_metrics[model]["test_mcc"]:.4f}.\n')
# Out:
# Optuna mode:
#
# Test ROC-AUC: 0.9109.
# Test average-precision score: 0.9587.
# Test Brier score: 0.1145.
# Test accuracy: 0.8242.
# Test MCC: 0.6266.

# %%
# Accuracy evaluated on test data:
for model in models:
  print(f'{mode} mode:')
  print(f'Test accuracy: {models[model].score(df_test.drop(drop_vars, axis=1), df_test["class"]):.4f}.')
# Out:
# Optuna mode:
# Test accuracy: 0.8226.

# %% [markdown]
# #### Model assessment

# %%
model_assess = {
    "estimation_id": str(estimation_id),
    "autoML": "mljar",
    "parameters": {
      "search_complexity": {
        "modes": modes, "total_time_limit": total_time_limit, "model_time_limit": model_time_limit, "optuna_time_budget": optuna_time_budget
      },
      "estimation": {
        "train_ensemble": train_ensemble, "stack_models": stack_models, "eval_metric": eval_metric, "validation_strategy": validation_strategy,
        "explain_level": explain_level
      },
      "computation": {
        "n_jobs": n_jobs
      }
    },
    "running_time": search_times,
    "performance_metrics": perf_metrics
}

# %% [markdown]
# ### Exporting the outcomes

# %%
if export:
  # Constructed ML pipelines:
  # compete_leaderboard.to_csv(f'../Datasets/Outcomes/mljar/compete_leaderboard_{estimation_id}.csv', index=False)
  optuna_leaderboard.to_csv(f'../Datasets/Outcomes/mljar/optuna_leaderboard_{estimation_id}.csv', index=False)

  # ML pipeline:
  # for mode in models:
    # pickle.dump(models[mode], open(f'../Datasets/Outcomes/mljar/model_{mode}_{estimation_id}.pickle', 'wb'))

  # Model assessment:
  with open(f'../Datasets/Outcomes/mljar/model_assess_{estimation_id}.json', 'w') as json_file:
    json.dump(model_assess, json_file, indent=2)
